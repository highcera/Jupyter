# %%
import xlwings as xw

# %%
bk = xw.Book('P:/상장법인목록')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-cfba93b5a300> in <module>
# ----> 1 bk = xw.Book('P:/상장법인목록')
#
# ~\anaconda3\lib\site-packages\xlwings\main.py in __init__(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load, impl)
#     545                     if not app:
#     546                         app = App(add_book=False)
# --> 547                     impl = app.books.open(fullname, update_links, read_only, format, password, write_res_password,
#     548                                           ignore_read_only_recommended, origin, delimiter, editable, notify, converter,
#     549                                           add_to_mru, local, corrupt_load).impl
#
# ~\anaconda3\lib\site-packages\xlwings\main.py in open(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load)
#    3835         fullname = utils.fspath(fullname)
#    3836         if not os.path.exists(fullname):
# -> 3837             raise FileNotFoundError("No such file: '%s'" % fullname)
#    3838         fullname = os.path.realpath(fullname)
#    3839         _, name = os.path.split(fullname)
#
# FileNotFoundError: No such file: 'p:/상장법인목록'

# %%
import os

# %%
os.listdir()
# Out:
# ['1-56편 종합.xlsx',
#  '201404212US(OPF2686US)-서명서류.pdf',
#  'A45601_OPIc IM_e-book_______20171113161606.pptx',
#  'Dc-bias_library_v2.xlsx',
#  'exam_OPIc_IM_w3_set1.pdf',
#  'Excel 서식 삭제 Macro',
#  'MClick Ver2.21.exe',
#  '~$Dc-bias_library_v2.xlsx',
#  '강정분석_갤럽.pptx',
#  '경력사항.xlsx',
#  '교안.pptx',
#  '막판뒤집기 OPIC.pdf',
#  '복사본 부서원 연장근무 현황_20211001083025.xlsx',
#  '복사본 주식_종목_리스트.xlsx',
#  '상장법인목록.xlsx',
#  '새 폴더',
#  '소영.txt',
#  '양식',
#  '인공지능(AI) 프로그래밍.txt',
#  '일본어 메일',
#  '조홍연(20411017)_등본.pdf',
#  '주소록',
#  '주식_종목_리스트.xlsx',
#  '주식_종목_리스트2.xlsx',
#  '주식_종목_리스트3.xlsx',
#  '주식_종목_리스트4.xlsx',
#  '처음 데이터분석 파이썬',
#  '프레젠테이션1.pptx']

# %%
os.chdir("P:\개인자료")

# %%
bk = xw.Book('주식_종목_리스트.xlsx')

# %%
bk.name
# Out:
# '주식_종목_리스트.xlsx'

# %%
bk.sheets.count
# Out:
# 2

# %%
bk.sheets(1)
# Out:
# <Sheet [주식_종목_리스트.xlsx]종목리스트>

# %%
sh1 = bk.sheets(1)

# %%
sh2 = bk.sheets('sheet2')

# %%
sh1.name
# Out:
# '종목리스트'

# %%
sh2.name
# Out:
# 'Sheet2'

# %%
sh2.delete()

# %%
a=sh1['A1'].value
b=sh1['C2'].value
c=sh1['A1:A4'].value
d=sh1['A1:B2'].value

print(a, type(a))
print(b, type(b))
print(c)
print(d)
# Out:
# 종목코드 <class 'str'>
# 82600.0 <class 'float'>
# ['종목코드', 'A005930', 'A051910', 'A035420']
# [['종목코드', '종목명'], ['A005930', '삼성전자']]

# %%
dtn = sh1['A2:B7'].options(dict).value
dtn
# Out:
# {'A005930': '삼성전자',
#  'A051910': 'LG화학',
#  'A035420': 'NAVER',
#  'A005380': '현대차',
#  'A035720': '카카오',
#  'A068270': '셀트리온'}

# %%
import pandas as pd
sr = sh1['A1:B7'].options(pd.Series).value
sr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c6081e2b509c> in <module>
#       1 import pandas as pd
# ----> 2 sr = sh1['A1:B7'].options(pd.Series).value
#       3 sr
#
# NameError: name 'sh1' is not defined

# %%
df = sh1['A1:E7'].options(pd.DataFrame).value
df
# Out:
#            종목명     주가(원)    시가총액(백만원)    섹터
# 종목코드
# A005930   삼성전자   82600.0  493104039.0  전기전자
# A051910   LG화학  941000.0   66427395.0    화학
# A035420  NAVER  398000.0   65376831.0    IT
# A005380    현대차  242000.0   51707701.0   자동차
# A035720    카카오  504000.0   44689512.0    IT
# A068270   셀트리온  318500.0   43858542.0   바이오

# %%
def automate_excel(file_name):
    bk = xw.Book(file_name)
    sh = bk.sheets(1)
    df = sh['A1:E7'].options(pd.DataFrame).value
    return df

df_auto = automate_excel('주식_종목_리스트2.xlsx')
df_auto
# Out:
#            종목명     주가(원)   시가총액(백만원)     섹터
# 종목코드
# A000270     기아   85500.0  34658566.0  경기소비재
# A036570  엔씨소프트  885000.0  19429309.0     IT
# A032830   삼성생명   78000.0  15600000.0     금융
# NaN       None       NaN         NaN   None
# NaN       None       NaN         NaN   None
# NaN       None       NaN         NaN   None

# %%
df1 = sh1['A1:E7'].options(pd.DataFrame).value
df2 = sh1['A1:E1'].options(pd.DataFrame, expand='down')
df3 = sh1['A1:A7'].options(pd.DataFrame, expand='right')
df4 = sh1['A1'].options(pd.DataFrame, expand='table')

# %%
df1
# Out:
#            종목명     주가(원)    시가총액(백만원)    섹터
# 종목코드
# A005930   삼성전자   82600.0  493104039.0  전기전자
# A051910   LG화학  941000.0   66427395.0    화학
# A035420  NAVER  398000.0   65376831.0    IT
# A005380    현대차  242000.0   51707701.0   자동차
# A035720    카카오  504000.0   44689512.0    IT
# A068270   셀트리온  318500.0   43858542.0   바이오

# %%
df2
# Out:
# <Range [주식_종목_리스트.xlsx]종목리스트!$A$1:$E$1>

# %%
df3
# Out:
# <Range [주식_종목_리스트.xlsx]종목리스트!$A$1:$A$7>

# %%
df4
# Out:
# <Range [주식_종목_리스트.xlsx]종목리스트!$A$1>

# %%
def automate_excel(file_name):
    bk = xw.Book(file_name)
    sh = bk.sheets(1)
    df = sh['A1'].options(pd.DataFrame, expand='table').value
    # 또는 sh['A1:E1'].options(pd.DataFrame, expand='down').value
    return df

df_auto = automate_excel('주식_종목_리스트.xlsx')
df_auto2 = automate_excel('주식_종목_리스트2.xlsx')
df_auto3 = automate_excel('주식_종목_리스트3.xlsx')
df_auto4 = automate_excel('주식_종목_리스트4.xlsx')

# %%
df_auto4
# Out:
#              종목명     주가(원)   시가총액(백만원)     섹터
# 종목코드
# A028260     삼성물산  125000.0  23360885.0    산업재
# A017670    SK텔레콤  279000.0  22528053.0  통신서비스
# A066570     LG전자  154500.0  25283587.0  경기소비재
# A105560     KB금융   54600.0  22703112.0     금융
# A096770  SK이노베이션  232500.0  21498244.0    에너지

# %%
import pandas as pd
bk2 = xw.Book('Dc-bias_library_V2.xlsx')

# %%
df = bk2.sheets(1).used_range.options(pd.DataFrame).value

# %%
df
# Out:
#             NaN    NaN           NaN      NaN   NaN                 NaN  \
# NaN         NaT    NaN            기종      Lot  사이즈                   조성
# NaN         NaT    1.0     05W225MS2  AHBDK14    05  SHBT100(NA392T010)
# NaN         NaT    2.0     05W225MS2  AHBDK14    05  SHBT100(NA392T010)
# NaN         NaT    3.0     05X106MQ5  AH99B1K    05  SHBT100(NA392T010)
# NaN         NaT    4.0     05X106MQ5  AH99B1K    05  SHBT100(NA392T010)
# ...         ...    ...           ...      ...   ...                 ...
# 임봉섭P 2022-05-31  268.0  03A475MQ5C65  AG3GB6Y    03   SHBT70(NA272PUG1)
# 임봉섭P 2022-05-31  269.0  03A225MP3ORN  AG8SB9C    03   SHBT70(NA272PUG1)
# 임봉섭P 2022-05-31  270.0  03A225MP3ORN  AG8TB9N    03   SHBT70(NA272PUG1)
# 임봉섭P 2022-05-31  271.0  03A225MP3OR2  AG6LB7K    03   SHBT70(NA272PUG1)
# 임봉섭P 2022-05-31  272.0  03A225MP3OR2  AG6KB1Y    03   SHBT70(NA272PUG1)
#
#            NaN          NaN       NaN         NaN  ...   NaN   NaN   NaN  \
# NaN   sheet 두께          유전율        DF  DC-Bias 측정  ...  None  None  None
# NaN        1.1       2828.0     0.061         저주파  ...  None  None  None
# NaN        1.1       2828.0     0.061         고주파  ...  None  None  None
# NaN        1.2  3815.160464     0.071         저주파  ...  None  None  None
# NaN        1.2  3815.160464     0.071         고주파  ...     a    a'     b
# ...        ...          ...       ...         ...  ...   ...   ...   ...
# 임봉섭P       0.8  4250.862483  0.071927         저주파  ...  None  None  None
# 임봉섭P      0.83  3451.966696  0.056869         저주파  ...  None  None  None
# 임봉섭P      0.83  3027.544485  0.051773         저주파  ...  None  None  None
# 임봉섭P      0.92  3662.634407  0.060282         저주파  ...  None  None  None
# 임봉섭P      0.92  3871.594778  0.073715         저주파  ...  None  None  None
#
#        NaN   NaN   NaN   NaN        NaN       NaN         NaN
# NaN   None  None  None  None       None      None        None
# NaN   None  None  None  None       None      None    최종 예측 치
# NaN   None  None  None  None       None        예측          예측
# NaN   None  None  None  None  Log(1+전계)  Log(변화율)      변화율 환산
# NaN      c     d     f  None        0.0  2.005723  101.326564
# ...    ...   ...   ...   ...        ...       ...         ...
# 임봉섭P  None  None  None  None       None      None        None
# 임봉섭P  None  None  None  None       None      None        None
# 임봉섭P  None  None  None  None       None      None        None
# 임봉섭P  None  None  None  None       None      None        None
# 임봉섭P  None  None  None  None       None      None        None
#
# [270 rows x 58 columns]

# %%
df2 = pd.DataFrame(df.iloc[1:, :21].dropna(axis = 0, how = 'all').values, columns = df.iloc[0, :21].values)

# %%
df2
# Out:
#            NaN    NaN            기종      Lot 사이즈                   조성  \
# 0          NaT    1.0     05W225MS2  AHBDK14   05  SHBT100(NA392T010)
# 1          NaT    2.0     05W225MS2  AHBDK14   05  SHBT100(NA392T010)
# 2          NaT    3.0     05X106MQ5  AH99B1K   05  SHBT100(NA392T010)
# 3          NaT    4.0     05X106MQ5  AH99B1K   05  SHBT100(NA392T010)
# 4          NaT    5.0     31B105KCH  AH3EB3C   31  NBT05(NB202P1 70%)
# ..         ...    ...           ...      ...  ...                 ...
# 264 2022-05-31  268.0  03A475MQ5C65  AG3GB6Y   03   SHBT70(NA272PUG1)
# 265 2022-05-31  269.0  03A225MP3ORN  AG8SB9C   03   SHBT70(NA272PUG1)
# 266 2022-05-31  270.0  03A225MP3ORN  AG8TB9N   03   SHBT70(NA272PUG1)
# 267 2022-05-31  271.0  03A225MP3OR2  AG6LB7K   03   SHBT70(NA272PUG1)
# 268 2022-05-31  272.0  03A225MP3OR2  AG6KB1Y   03   SHBT70(NA272PUG1)
#
#     sheet 두께          유전율        DF DC-Bias 측정  ... AC(V) 전압유지시간 Aging 시간  \
# 0        1.1       2828.0     0.061        저주파  ...   0.5    60s     24hr
# 1        1.1       2828.0     0.061        고주파  ...  0.01    60s     24hr
# 2        1.2  3815.160464     0.071        저주파  ...   0.5    60s     24hr
# 3        1.2  3815.160464     0.071        고주파  ...  0.01    60s     24hr
# 4       15.7  3940.941869  0.011336        저주파  ...   1.0    60s     24hr
# ..       ...          ...       ...        ...  ...   ...    ...      ...
# 264      0.8  4250.862483  0.071927        저주파  ...   1.0     3s     24hr
# 265     0.83  3451.966696  0.056869        저주파  ...   1.0     3s     24hr
# 266     0.83  3027.544485  0.051773        저주파  ...   1.0     3s     24hr
# 267     0.92  3662.634407  0.060282        저주파  ...   1.0     3s     24hr
# 268     0.92  3871.594778  0.073715        저주파  ...   1.0     3s     24hr
#
#         전계 영역         a        a'         b          c         d         f
# 0    5.727273 -6.663013  6.663013  0.389756  -824364.0  2.018156       0.0
# 1    5.727273 -7.667761  7.667761  0.463241  -611647.3  2.008805       0.0
# 2        5.25 -11.39497  11.39497   0.27856 -1011754.0  2.007298       0.0
# 3        5.25 -11.42617  11.42617  0.325849  -782284.9  2.008849       0.0
# 4    2.547771 -13.75936  13.75936  0.375514  -335286.4  2.002235       0.0
# ..        ...       ...       ...       ...        ...       ...       ...
# 264     7.875 -8.191007  8.191007  0.465081   0.255943  2.008744  0.218004
# 265  7.590361 -8.654993  8.654993  0.432787  -1.270904   2.00487  0.061921
# 266  7.590361 -8.093796  8.093796  0.458168  -0.236801  2.007394   0.12854
# 267  6.847826  -9.09402   9.09402    0.3858  -0.338286  2.006928  0.097851
# 268  6.847826 -8.250924  8.250924  0.437632  -0.004494   2.00948  0.167141
#
# [269 rows x 21 columns]

# %%
vol_lev = [x[7] for x in df2["기종"]]
df2.insert(len(df2.columns), 'vol_lev', vol_lev)
df2.insert(len(df2.columns), '전압 (Vdc)', 0)

# %%
df2
# Out:
#            NaN    NaN            기종      Lot 사이즈                   조성  \
# 0          NaT    1.0     05W225MS2  AHBDK14   05  SHBT100(NA392T010)
# 1          NaT    2.0     05W225MS2  AHBDK14   05  SHBT100(NA392T010)
# 2          NaT    3.0     05X106MQ5  AH99B1K   05  SHBT100(NA392T010)
# 3          NaT    4.0     05X106MQ5  AH99B1K   05  SHBT100(NA392T010)
# 4          NaT    5.0     31B105KCH  AH3EB3C   31  NBT05(NB202P1 70%)
# ..         ...    ...           ...      ...  ...                 ...
# 264 2022-05-31  268.0  03A475MQ5C65  AG3GB6Y   03   SHBT70(NA272PUG1)
# 265 2022-05-31  269.0  03A225MP3ORN  AG8SB9C   03   SHBT70(NA272PUG1)
# 266 2022-05-31  270.0  03A225MP3ORN  AG8TB9N   03   SHBT70(NA272PUG1)
# 267 2022-05-31  271.0  03A225MP3OR2  AG6LB7K   03   SHBT70(NA272PUG1)
# 268 2022-05-31  272.0  03A225MP3OR2  AG6KB1Y   03   SHBT70(NA272PUG1)
#
#     sheet 두께          유전율        DF DC-Bias 측정  ... Aging 시간     전계 영역  \
# 0        1.1       2828.0     0.061        저주파  ...     24hr  5.727273
# 1        1.1       2828.0     0.061        고주파  ...     24hr  5.727273
# 2        1.2  3815.160464     0.071        저주파  ...     24hr      5.25
# 3        1.2  3815.160464     0.071        고주파  ...     24hr      5.25
# 4       15.7  3940.941869  0.011336        저주파  ...     24hr  2.547771
# ..       ...          ...       ...        ...  ...      ...       ...
# 264      0.8  4250.862483  0.071927        저주파  ...     24hr     7.875
# 265     0.83  3451.966696  0.056869        저주파  ...     24hr  7.590361
# 266     0.83  3027.544485  0.051773        저주파  ...     24hr  7.590361
# 267     0.92  3662.634407  0.060282        저주파  ...     24hr  6.847826
# 268     0.92  3871.594778  0.073715        저주파  ...     24hr  6.847826
#
#             a        a'         b          c         d         f vol_lev  \
# 0   -6.663013  6.663013  0.389756  -824364.0  2.018156       0.0       S
# 1   -7.667761  7.667761  0.463241  -611647.3  2.008805       0.0       S
# 2   -11.39497  11.39497   0.27856 -1011754.0  2.007298       0.0       Q
# 3   -11.42617  11.42617  0.325849  -782284.9  2.008849       0.0       Q
# 4   -13.75936  13.75936  0.375514  -335286.4  2.002235       0.0       C
# ..        ...       ...       ...        ...       ...       ...     ...
# 264 -8.191007  8.191007  0.465081   0.255943  2.008744  0.218004       Q
# 265 -8.654993  8.654993  0.432787  -1.270904   2.00487  0.061921       P
# 266 -8.093796  8.093796  0.458168  -0.236801  2.007394   0.12854       P
# 267  -9.09402   9.09402    0.3858  -0.338286  2.006928  0.097851       P
# 268 -8.250924  8.250924  0.437632  -0.004494   2.00948  0.167141       P
#
#     전압 (Vdc)
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 264        0
# 265        0
# 266        0
# 267        0
# 268        0
#
# [269 rows x 23 columns]

# %%
mat = list(set(df2["조성"]))
mat = [x for x in mat if pd.isnull(x) == False]
mat.sort()

# %%
mat
# Out:
# ['BT-HP150SP',
#  'GSBT02(NA272PT112)',
#  'HDBT+DRC100100',
#  'HDBT1.5_70 + DRC',
#  'HDBT3-70(NA272PUG1)',
#  'KBT015(A210)',
#  'KBT015(NA272PT112)',
#  'KBT015(NB202P1 80%)',
#  'KBT015+342AT01',
#  'KBT015+392T010',
#  'KBT025(NB242P002)',
#  'KBT025/BCT300(202AH02)',
#  'KBT250+RF002',
#  'NBT05(262C)',
#  'NBT05(NB202P1 100%)',
#  'NBT05(NB202P1 70%)',
#  'NBT05(NB202P1 75%)',
#  'NBT05(NB202P1 80%)',
#  'SBT030(NA272PT112)',
#  'SEBT+DRC100100',
#  'SEBT+DRC50100',
#  'SHBT100(NA272P012)',
#  'SHBT100(NA272PT112)',
#  'SHBT100(NA372PA01)',
#  'SHBT100(NA382P010)',
#  'SHBT100(NA392T010)',
#  'SHBT100(NB202P1)',
#  'SHBT160(A003)',
#  'SHBT160(NA272PT112)',
#  'SHBT160(NB302A010)',
#  'SHBT160(NB302A010) ',
#  'SHBT160(NB322P001) ',
#  'SHBT160+A010',
#  'SHBT50(NA272PUG2)',
#  'SHBT70(NA272PUG1)',
#  'SHBT70+392TDRC',
#  'SPBT70-DRC ',
#  'SPMCBT 70nm DRC75% ']

# %%
lib = pd.DataFrame(df2, columns = ["조성","유전율", "vol_lev", "DC-Bias 측정", '전압 (Vdc)', 'sheet 두께', 'DF', '주파수(kHz)', 'AC(V)', '전압유지시간', 'Aging 시간'])

# %%
lib
# Out:
#                      조성          유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께  \
# 0    SHBT100(NA392T010)       2828.0       S        저주파         0      1.1
# 1    SHBT100(NA392T010)       2828.0       S        고주파         0      1.1
# 2    SHBT100(NA392T010)  3815.160464       Q        저주파         0      1.2
# 3    SHBT100(NA392T010)  3815.160464       Q        고주파         0      1.2
# 4    NBT05(NB202P1 70%)  3940.941869       C        저주파         0     15.7
# ..                  ...          ...     ...        ...       ...      ...
# 264   SHBT70(NA272PUG1)  4250.862483       Q        저주파         0      0.8
# 265   SHBT70(NA272PUG1)  3451.966696       P        저주파         0     0.83
# 266   SHBT70(NA272PUG1)  3027.544485       P        저주파         0     0.83
# 267   SHBT70(NA272PUG1)  3662.634407       P        저주파         0     0.92
# 268   SHBT70(NA272PUG1)  3871.594778       P        저주파         0     0.92
#
#            DF 주파수(kHz) AC(V) 전압유지시간 Aging 시간
# 0       0.061      1.0   0.5    60s     24hr
# 1       0.061    100.0  0.01    60s     24hr
# 2       0.071      1.0   0.5    60s     24hr
# 3       0.071    100.0  0.01    60s     24hr
# 4    0.011336      1.0   1.0    60s     24hr
# ..        ...      ...   ...    ...      ...
# 264  0.071927      1.0   1.0     3s     24hr
# 265  0.056869      1.0   1.0     3s     24hr
# 266  0.051773      1.0   1.0     3s     24hr
# 267  0.060282      1.0   1.0     3s     24hr
# 268  0.073715      1.0   1.0     3s     24hr
#
# [269 rows x 11 columns]

# %%
lib["유전율"] = [int(x) if x != '사이즈 없음' else x for x in lib['유전율']]

# %%
lib
# Out:
#                      조성   유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께        DF  \
# 0    SHBT100(NA392T010)  2828       S        저주파         0      1.1     0.061
# 1    SHBT100(NA392T010)  2828       S        고주파         0      1.1     0.061
# 2    SHBT100(NA392T010)  3815       Q        저주파         0      1.2     0.071
# 3    SHBT100(NA392T010)  3815       Q        고주파         0      1.2     0.071
# 4    NBT05(NB202P1 70%)  3940       C        저주파         0     15.7  0.011336
# ..                  ...   ...     ...        ...       ...      ...       ...
# 264   SHBT70(NA272PUG1)  4250       Q        저주파         0      0.8  0.071927
# 265   SHBT70(NA272PUG1)  3451       P        저주파         0     0.83  0.056869
# 266   SHBT70(NA272PUG1)  3027       P        저주파         0     0.83  0.051773
# 267   SHBT70(NA272PUG1)  3662       P        저주파         0     0.92  0.060282
# 268   SHBT70(NA272PUG1)  3871       P        저주파         0     0.92  0.073715
#
#     주파수(kHz) AC(V) 전압유지시간 Aging 시간
# 0        1.0   0.5    60s     24hr
# 1      100.0  0.01    60s     24hr
# 2        1.0   0.5    60s     24hr
# 3      100.0  0.01    60s     24hr
# 4        1.0   1.0    60s     24hr
# ..       ...   ...    ...      ...
# 264      1.0   1.0     3s     24hr
# 265      1.0   1.0     3s     24hr
# 266      1.0   1.0     3s     24hr
# 267      1.0   1.0     3s     24hr
# 268      1.0   1.0     3s     24hr
#
# [269 rows x 11 columns]

# %%
show = lib.drop(['vol_lev', '전압 (Vdc)', 'DF','주파수(kHz)', 'AC(V)', '전압유지시간', 'Aging 시간'], axis=1)
