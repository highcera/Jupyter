# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Untitled Folder'

# %%
import pandas as pd

# %%
bike_data = pd.read_csv('data/bike_usage_0.csv')

# %%
bike_data
# Out:
#          Date_out  Time_out  Station_no_out                Station_out  \
# 0      2019-10-03         0             129  129. ���̿�(2ȣ��) 6���ⱸ ��
# 1      2019-10-03         0             150       150. �����뿪 2���ⱸ ��
# 2      2019-10-03         0             240       240. ������ 4���ⱸ ��
# 3      2019-10-03         0             623      623. ����ø��� ���� ��
# 4      2019-10-03         0             633      633. û���� ������� ��
# ...           ...       ...             ...                        ...
# 36590  2019-10-05        23             130  130. ���̿�(2ȣ��) 7���ⱸ ��
# 36591  2019-10-05        23            2215      2215. �������տ�� �Ա�
# 36592  2019-10-05        23             654           654. ���� �԰����
# 36593  2019-10-05        23             119         119. �������� ����
# 36594  2019-10-05        23             630          630. ���빮�� ���Ǽ�
#
#       Membership_type Gender Age_Group Momentum  Station_no_in  \
# 0               �����    NaN     ~10��    28.27            122
# 1               �����    NaN      20��   146.46           2065
# 2               �����    NaN      20��    37.13            245
# 3               �����    NaN      20��   134.62           1346
# 4               �����    NaN      20��    85.83            568
# ...               ...    ...       ...      ...            ...
# 36590           ���ϱ�      M      30��   110.06            432
# 36591           ���ϱ�      M      30��   153.15           2221
# 36592           ���ϱ�      M      40��    65.12            654
# 36593           ���ϱ�      M      40��    78.76           3102
# 36594           ��ü��    NaN      20��    22.83            660
#
#                Station_in                   Date_in    Bike_no Carbon_amount  \
# 0             �ż����Ĵ� ��  2019-10-03 ���� 12:20:42  SPB-15000          0.24
# 1         ����ÿ����������   2019-10-03 ���� 1:16:32  SPB-13087          1.32
# 2         �Ｚ���� ����� ��  2019-10-03 ���� 12:18:21  SPB-23229          0.29
# 3        ����8���̰��� ��   2019-10-03 ���� 1:15:39  SPB-14181          1.21
# 4          û��8����Ÿ� �α�  2019-10-03 ���� 12:17:58  SPB-15221          0.67
# ...                   ...                       ...        ...           ...
# 36590        �����߾ӵ�����  2019-10-06 ���� 12:06:20  SPB-14263           0.9
# 36591  �ϳ����� ��赿���� ��  2019-10-06 ���� 12:27:55  SPB-17557          1.38
# 36592         ���� �԰����  2019-10-06 ���� 12:09:12  SPB-18226          0.59
# 36593             �����Ÿ�  2019-10-05 ���� 11:44:39  SPB-21624          0.71
# 36594          ���Ǻ���Ÿ��  2019-10-05 ���� 11:27:13  SPB-02538          0.14
#
#        Distance  Duration
# 0          1050         5
# 1          5690        32
# 2          1250        10
# 3          5230        24
# 4          2890        11
# ...         ...       ...
# 36590      3860        23
# 36591      5950        32
# 36592      2530        17
# 36593      3060        17
# 36594       620         5
#
# [36595 rows x 15 columns]

# %%
bike_data = pd.read_csv('data/bike_usage_0.csv', encoding = 'ANSI')

# %%
bike_data
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권    NaN      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권    NaN       20대   146.46           2065     서울시여성가족재단
# 2                 정기권    NaN       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권    NaN       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권    NaN       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36590             일일권      M       30대   110.06            432       마포중앙도서관
# 36591             일일권      M       30대   153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대    65.12            654      전농동 텃골공원
# 36593             일일권      M       40대    78.76           3102         연희삼거리
# 36594             단체권    NaN       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.9      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557          1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226          0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624          0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [36595 rows x 15 columns]

# %%
print(bike_data)
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권    NaN      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권    NaN       20대   146.46           2065     서울시여성가족재단
# 2                 정기권    NaN       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권    NaN       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권    NaN       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36590             일일권      M       30대   110.06            432       마포중앙도서관
# 36591             일일권      M       30대   153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대    65.12            654      전농동 텃골공원
# 36593             일일권      M       40대    78.76           3102         연희삼거리
# 36594             단체권    NaN       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.9      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557          1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226          0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624          0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [36595 rows x 15 columns]

# %%
bike_data.isnull()
# Out:
#        Date_out  Time_out  Station_no_out  Station_out  Membership_type  \
# 0         False     False           False        False            False
# 1         False     False           False        False            False
# 2         False     False           False        False            False
# 3         False     False           False        False            False
# 4         False     False           False        False            False
# ...         ...       ...             ...          ...              ...
# 36590     False     False           False        False            False
# 36591     False     False           False        False            False
# 36592     False     False           False        False            False
# 36593     False     False           False        False            False
# 36594     False     False           False        False            False
#
#        Gender  Age_Group  Momentum  Station_no_in  Station_in  Date_in  \
# 0        True      False     False          False       False    False
# 1        True      False     False          False       False    False
# 2        True      False     False          False       False    False
# 3        True      False     False          False       False    False
# 4        True      False     False          False       False    False
# ...       ...        ...       ...            ...         ...      ...
# 36590   False      False     False          False       False    False
# 36591   False      False     False          False       False    False
# 36592   False      False     False          False       False    False
# 36593   False      False     False          False       False    False
# 36594    True      False     False          False       False    False
#
#        Bike_no  Carbon_amount  Distance  Duration
# 0        False          False     False     False
# 1        False          False     False     False
# 2        False          False     False     False
# 3        False          False     False     False
# 4        False          False     False     False
# ...        ...            ...       ...       ...
# 36590    False          False     False     False
# 36591    False          False     False     False
# 36592    False          False     False     False
# 36593    False          False     False     False
# 36594    False          False     False     False
#
# [36595 rows x 15 columns]

# %%
bike_data.isnull().sum()
# Out:
# Date_out               0
# Time_out               0
# Station_no_out         0
# Station_out            0
# Membership_type        0
# Gender             18333
# Age_Group              0
# Momentum               0
# Station_no_in          0
# Station_in             0
# Date_in                0
# Bike_no                0
# Carbon_amount          0
# Distance               0
# Duration               0
# dtype: int64

# %%
population = pd.read_csv('data\population_by_Gu.txt')

# %%
population
# Out:
#   Gu\tFamily\tPopulation\tMale\tFemale\tD_Total\tD_Male\tD_Female\tF_Total\tF_Male\tF_Female\tper_Family\tover_65
# 0  동대문구\t164191\t363023\t178490\t184533\t346194\t...
# 1  은평구\t207681\t484546\t233360\t251186\t480032\t2...
# 2  마포구\t175023\t385925\t181303\t204622\t374035\t1...
# 3  영등포구\t174806\t400986\t200986\t200000\t367678\t...
# 4  서초구\t173199\t435107\t208181\t226926\t430826\t2...

# %%
population = pd.read_csv('data\population_by_Gu.txt',sep='\t')

# %%
population
# Out:
#      Gu  Family  Population    Male  Female  D_Total  D_Male  D_Female  \
# 0  동대문구  164191      363023  178490  184533   346194  172113    174081
# 1   은평구  207681      484546  233360  251186   480032  231528    248504
# 2   마포구  175023      385925  181303  204622   374035  176891    197144
# 3  영등포구  174806      400986  200986  200000   367678  182438    185240
# 4   서초구  173199      435107  208181  226926   430826  206039    224787
#
#    F_Total  F_Male  F_Female  per_Family  over_65
# 0    16829    6377     10452        2.11    59350
# 1     4514    1832      2682        2.31    80738
# 2    11890    4412      7478        2.14    52429
# 3    33308   18548     14760        2.10    57872
# 4     4281    2142      2139        2.49    57136

# %%
weather = pd.read_csv('data\weather.csv')

# %%
weather
# Out:
#                     date_old        date  time  temp  cum_precipitation  \
# 0     2019-10-03 오전 12:00:00  2019-10-03    12  20.0               23.2
# 1     2019-10-03 오전 12:01:00  2019-10-03    12  20.1                0.0
# 2     2019-10-03 오전 12:02:00  2019-10-03    12  20.0                0.0
# 3     2019-10-03 오전 12:03:00  2019-10-03    12  20.0                0.0
# 4     2019-10-03 오전 12:04:00  2019-10-03    12  20.0                0.0
# ...                      ...         ...   ...   ...                ...
# 4315  2019-10-05 오후 11:55:00  2019-10-05    23  14.8                0.6
# 4316  2019-10-05 오후 11:56:00  2019-10-05    23  14.8                0.6
# 4317  2019-10-05 오후 11:57:00  2019-10-05    23  14.8                0.6
# 4318  2019-10-05 오후 11:58:00  2019-10-05    23  14.7                0.6
# 4319  2019-10-05 오후 11:59:00  2019-10-05    23  14.8                0.6
#
#       humidity  insolation  sunshine  wind  wind_direction  sea_lvl_pressure  \
# 0         94.1        3.40         0   5.5           351.7            1004.1
# 1         94.1        0.00         0   3.7           348.6            1004.1
# 2         94.1        0.00         0   3.6           346.4            1004.1
# 3         94.1        0.00         0   3.1           349.1            1004.1
# 4         94.0        0.00         0   3.4           335.9            1004.1
# ...        ...         ...       ...   ...             ...               ...
# 4315      63.6        8.24      8400   3.2           350.9            1021.3
# 4316      63.5        8.24      8400   2.9           354.3            1021.3
# 4317      63.7        8.24      8400   3.1             3.9            1021.3
# 4318      63.9        8.24      8400   2.3            10.0            1021.2
# 4319      64.0        8.24      8400   2.6           351.7            1021.3
#
#       pressure
# 0        994.2
# 1        994.2
# 2        994.2
# 3        994.2
# 4        994.2
# ...        ...
# 4315    1011.0
# 4316    1011.0
# 4317    1011.0
# 4318    1011.0
# 4319    1011.0
#
# [4320 rows x 12 columns]

# %%
bike_data.describe()
# Out:
#            Time_out  Station_no_out  Station_no_in       Distance  \
# count  36595.000000    36595.000000   36595.000000   36595.000000
# mean      14.318705      757.857467     885.718213    4213.292253
# std        6.000273      764.442285     835.058693    5713.148232
# min        0.000000      101.000000     101.000000       0.000000
# 25%       11.000000      225.000000     227.000000    1180.000000
# 50%       15.000000      417.000000     565.000000    2290.000000
# 75%       19.000000      926.000000    1351.000000    5080.000000
# max       23.000000     2511.000000    9997.000000  111270.000000
#
#            Duration
# count  36595.000000
# mean      31.020385
# std       32.073889
# min        1.000000
# 25%        9.000000
# 50%       19.000000
# 75%       44.000000
# max      682.000000

# %%
type(bike_data)
# Out:
# pandas.core.frame.DataFrame

# %%
bike_data.columns
# Out:
# Index(['Date_out', 'Time_out', 'Station_no_out', 'Station_out',
#        'Membership_type', 'Gender', 'Age_Group', 'Momentum', 'Station_no_in',
#        'Station_in', 'Date_in', 'Bike_no', 'Carbon_amount', 'Distance',
#        'Duration'],
#       dtype='object')

# %%
bike_data.head
# Out:
# <bound method NDFrame.head of          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권    NaN      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권    NaN       20대   146.46           2065     서울시여성가족재단
# 2                 정기권    NaN       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권    NaN       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권    NaN       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36590             일일권      M       30대   110.06            432       마포중앙도서관
# 36591             일일권      M       30대   153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대    65.12            654      전농동 텃골공원
# 36593             일일권      M       40대    78.76           3102         연희삼거리
# 36594             단체권    NaN       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.9      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557          1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226          0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624          0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [36595 rows x 15 columns]>

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36595 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36595 non-null  object
#  1   Time_out         36595 non-null  int64
#  2   Station_no_out   36595 non-null  int64
#  3   Station_out      36595 non-null  object
#  4   Membership_type  36595 non-null  object
#  5   Gender           18262 non-null  object
#  6   Age_Group        36595 non-null  object
#  7   Momentum         36595 non-null  object
#  8   Station_no_in    36595 non-null  int64
#  9   Station_in       36595 non-null  object
#  10  Date_in          36595 non-null  object
#  11  Bike_no          36595 non-null  object
#  12  Carbon_amount    36595 non-null  object
#  13  Distance         36595 non-null  int64
#  14  Duration         36595 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 4.2+ MB

# %%
bike_data.shape
# Out:
# (36595, 15)

# %%
bike_data.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권    NaN      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권    NaN       20대   146.46           2065     서울시여성가족재단
# 2                 정기권    NaN       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권    NaN       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권    NaN       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36590             일일권      M       30대   110.06            432       마포중앙도서관
# 36591             일일권      M       30대   153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대    65.12            654      전농동 텃골공원
# 36593             일일권      M       40대    78.76           3102         연희삼거리
# 36594             단체권    NaN       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.9      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557          1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226          0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624          0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [36595 rows x 15 columns]>

# %%
bike_data.Distance
# Out:
# 0        1050
# 1        5690
# 2        1250
# 3        5230
# 4        2890
#          ...
# 36590    3860
# 36591    5950
# 36592    2530
# 36593    3060
# 36594     620
# Name: Distance, Length: 36595, dtype: int64

# %%
bike_data.Distance.sum()
# Out:
# 154185430

# %%
bike_data['Distance']
# Out:
# 0        1050
# 1        5690
# 2        1250
# 3        5230
# 4        2890
#          ...
# 36590    3860
# 36591    5950
# 36592    2530
# 36593    3060
# 36594     620
# Name: Distance, Length: 36595, dtype: int64

# %%
bike_data['Distance'].sum()
# Out:
# 154185430

# %%
bike_data['Age_Group'].unique()
# Out:
# array(['~10대', '20대', '30대', '40대', '50대', '60대', '70대~'], dtype=object)

# %%
bike_data['Age_Group'].value_counts()
# Out:
# 20대     14504
# 30대      9491
# 40대      6127
# 50대      3226
# ~10대     2125
# 60대       939
# 70대~      183
# Name: Age_Group, dtype: int64

# %%
bike_data['Age_Group'].value_counts(normalize = True)
# Out:
# 20대     0.396338
# 30대     0.259352
# 40대     0.167427
# 50대     0.088154
# ~10대    0.058068
# 60대     0.025659
# 70대~    0.005001
# Name: Age_Group, dtype: float64

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36595 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36595 non-null  object
#  1   Time_out         36595 non-null  int64
#  2   Station_no_out   36595 non-null  int64
#  3   Station_out      36595 non-null  object
#  4   Membership_type  36595 non-null  object
#  5   Gender           18262 non-null  object
#  6   Age_Group        36595 non-null  object
#  7   Momentum         36595 non-null  object
#  8   Station_no_in    36595 non-null  int64
#  9   Station_in       36595 non-null  object
#  10  Date_in          36595 non-null  object
#  11  Bike_no          36595 non-null  object
#  12  Carbon_amount    36595 non-null  object
#  13  Distance         36595 non-null  int64
#  14  Duration         36595 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 4.2+ MB

# %%
bike_data.Momentum.isnull().sum()
# Out:
# 0

# %%
bike_data.Momentum.min()
# Out:
# '0'

# %%
bike_data.Momentum.max()
# Out:
# '\\N'

# %%
bike_data[bike_data.Momentum =='\\N']
# Out:
#          Date_out  Time_out  Station_no_out            Station_out  \
# 3347   2019-10-03        14             113      113. 홍대입구역 2번출구 앞
# 14547  2019-10-04        10             203     203. 국회의사당역 3번출구 옆
# 15697  2019-10-04        12             211       211. 여의도역 4번출구 옆
# 20683  2019-10-04        19             238        238. 제2구민체육센타 앞
# 25700  2019-10-05         3            2259  2259. 잠원역 3번-4번 출구사이
# 27995  2019-10-05        11             274   274. 영등포역지하쇼핑센타 5번출구
# 30112  2019-10-05        14             437          437. 대흥역 1번출구
# 32978  2019-10-05        18             274   274. 영등포역지하쇼핑센타 5번출구
# 34459  2019-10-05        20             146        146. 마포역 2번출구 뒤
#
#       Membership_type Gender Age_Group Momentum  Station_no_in  \
# 3347              정기권      F       30대       \N            113
# 14547             정기권      F      70대~       \N            214
# 15697             정기권      M       20대       \N            217
# 20683             정기권    NaN       20대       \N            238
# 25700             정기권    NaN       40대       \N           2217
# 27995             정기권    NaN       40대       \N            279
# 30112             정기권      M       30대       \N            135
# 32978             정기권      F       20대       \N            274
# 34459             정기권      F       20대       \N            109
#
#             Station_in                 Date_in    Bike_no Carbon_amount  \
# 3347      홍대입구역 2번출구 앞   2019-10-03 오후 7:56:30  SPB-19656            \N
# 14547          금융감독원 앞   2019-10-04 오전 8:41:49  SPB-14566            \N
# 15697         NH농협은행 앞  2019-10-04 오전 10:00:22  SPB-05742            \N
# 20683       제2구민체육센타 앞   2019-10-04 오후 8:34:07  SPB-18370            \N
# 25700      아크로리버뷰 부지 앞   2019-10-05 오후 9:23:46  SPB-03337            \N
# 27995     영등포 푸르지오 아파트  2019-10-05 오후 10:03:10  SPB-15669            \N
# 30112       명물길 원형무대 앞  2019-10-05 오후 10:55:50  SPB-17475            \N
# 32978  영등포역지하쇼핑센타 5번출구   2019-10-05 오후 3:46:34  SPB-16977            \N
# 34459           제일빌딩 앞   2019-10-05 오후 8:21:07  SPB-18232            \N
#
#        Distance  Duration
# 3347          0         2
# 14547         0         5
# 15697         0         5
# 20683         0         3
# 25700         0         7
# 27995         0        10
# 30112         0        10
# 32978         0         7
# 34459         0        19

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36595 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36595 non-null  object
#  1   Time_out         36595 non-null  int64
#  2   Station_no_out   36595 non-null  int64
#  3   Station_out      36595 non-null  object
#  4   Membership_type  36595 non-null  object
#  5   Gender           18262 non-null  object
#  6   Age_Group        36595 non-null  object
#  7   Momentum         36595 non-null  object
#  8   Station_no_in    36595 non-null  int64
#  9   Station_in       36595 non-null  object
#  10  Date_in          36595 non-null  object
#  11  Bike_no          36595 non-null  object
#  12  Carbon_amount    36595 non-null  object
#  13  Distance         36595 non-null  int64
#  14  Duration         36595 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 4.2+ MB

# %%
bike_data[bike_data.Gender.isnull()]
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36553  2019-10-05        23             106       106. 합정역 7번출구 앞
# 36554  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36555  2019-10-05        23            2222      2222.사당역 12번출구 뒤
# 36556  2019-10-05        23             916          916. 평생학습관 앞
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권    NaN      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권    NaN       20대   146.46           2065     서울시여성가족재단
# 2                 정기권    NaN       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권    NaN       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권    NaN       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36553             일일권    NaN       30대   383.64           1824     독산근린공원 입구
# 36554             일일권    NaN       30대   157.79           2221  하나은행 방배동지점 앞
# 36555             일일권    NaN       40대    51.74           2036  정금마을 마을버스정류장
# 36556             일일권    NaN       50대   274.94            916       평생학습관 앞
# 36594             단체권    NaN       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36553  2019-10-06 오전 12:48:32  SPB-23655          2.81     12110        68
# 36554  2019-10-06 오전 12:28:03  SPB-13792          1.42      6130        32
# 36555  2019-10-05 오후 11:52:33  SPB-17265          0.47      2010        15
# 36556   2019-10-06 오전 1:12:15  SPB-01580          3.04     13100        80
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [18333 rows x 15 columns]

# %%
bike_data.loc[bike_data.Gender.isnull(), 'Gender'] = 'U'

# %%
bike_data[bike_data.Gender.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration]
# Index: []

# %%
bike_data.Gender.value_counts()
# Out:
# U    18333
# M    11025
# F     7219
# m       14
# f        4
# Name: Gender, dtype: int64

# %%
bike_data[bike_data.Momentum =='\\N']
# Out:
#          Date_out  Time_out  Station_no_out            Station_out  \
# 3347   2019-10-03        14             113      113. 홍대입구역 2번출구 앞
# 14547  2019-10-04        10             203     203. 국회의사당역 3번출구 옆
# 15697  2019-10-04        12             211       211. 여의도역 4번출구 옆
# 20683  2019-10-04        19             238        238. 제2구민체육센타 앞
# 25700  2019-10-05         3            2259  2259. 잠원역 3번-4번 출구사이
# 27995  2019-10-05        11             274   274. 영등포역지하쇼핑센타 5번출구
# 30112  2019-10-05        14             437          437. 대흥역 1번출구
# 32978  2019-10-05        18             274   274. 영등포역지하쇼핑센타 5번출구
# 34459  2019-10-05        20             146        146. 마포역 2번출구 뒤
#
#       Membership_type Gender Age_Group Momentum  Station_no_in  \
# 3347              정기권      F       30대       \N            113
# 14547             정기권      F      70대~       \N            214
# 15697             정기권      M       20대       \N            217
# 20683             정기권      U       20대       \N            238
# 25700             정기권      U       40대       \N           2217
# 27995             정기권      U       40대       \N            279
# 30112             정기권      M       30대       \N            135
# 32978             정기권      F       20대       \N            274
# 34459             정기권      F       20대       \N            109
#
#             Station_in                 Date_in    Bike_no Carbon_amount  \
# 3347      홍대입구역 2번출구 앞   2019-10-03 오후 7:56:30  SPB-19656            \N
# 14547          금융감독원 앞   2019-10-04 오전 8:41:49  SPB-14566            \N
# 15697         NH농협은행 앞  2019-10-04 오전 10:00:22  SPB-05742            \N
# 20683       제2구민체육센타 앞   2019-10-04 오후 8:34:07  SPB-18370            \N
# 25700      아크로리버뷰 부지 앞   2019-10-05 오후 9:23:46  SPB-03337            \N
# 27995     영등포 푸르지오 아파트  2019-10-05 오후 10:03:10  SPB-15669            \N
# 30112       명물길 원형무대 앞  2019-10-05 오후 10:55:50  SPB-17475            \N
# 32978  영등포역지하쇼핑센타 5번출구   2019-10-05 오후 3:46:34  SPB-16977            \N
# 34459           제일빌딩 앞   2019-10-05 오후 8:21:07  SPB-18232            \N
#
#        Distance  Duration
# 3347          0         2
# 14547         0         5
# 15697         0         5
# 20683         0         3
# 25700         0         7
# 27995         0        10
# 30112         0        10
# 32978         0         7
# 34459         0        19

# %%
import numpy as np

bike_data.loc[bike_data.Momentum == '\\N', 'Momentum'] = np.nan

# %%
bike_data[bike_data.Momentum == '\\N']
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration]
# Index: []

# %%
bike_data.dropna()
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group Momentum  Station_no_in    Station_in  \
# 0                 정기권      U      ~10대    28.27            122      신성기사식당 앞
# 1                 정기권      U       20대   146.46           2065     서울시여성가족재단
# 2                 정기권      U       20대    37.13            245   삼성생명 당산사옥 앞
# 3                 정기권      U       20대   134.62           1346   길음8골어린이공원 옆
# 4                 정기권      U       20대    85.83            568    청계8가사거리 부근
# ...               ...    ...       ...      ...            ...           ...
# 36590             일일권      M       30대   110.06            432       마포중앙도서관
# 36591             일일권      M       30대   153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대    65.12            654      전농동 텃골공원
# 36593             일일권      M       40대    78.76           3102         연희삼거리
# 36594             단체권      U       20대    22.83            660        동의보감타워
#
#                       Date_in    Bike_no Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000          0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087          1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229          0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181          1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221          0.67      2890        11
# ...                       ...        ...           ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.9      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557          1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226          0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624          0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538          0.14       620         5
#
# [36586 rows x 15 columns]

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36595 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36595 non-null  object
#  1   Time_out         36595 non-null  int64
#  2   Station_no_out   36595 non-null  int64
#  3   Station_out      36595 non-null  object
#  4   Membership_type  36595 non-null  object
#  5   Gender           36595 non-null  object
#  6   Age_Group        36595 non-null  object
#  7   Momentum         36586 non-null  object
#  8   Station_no_in    36595 non-null  int64
#  9   Station_in       36595 non-null  object
#  10  Date_in          36595 non-null  object
#  11  Bike_no          36595 non-null  object
#  12  Carbon_amount    36595 non-null  object
#  13  Distance         36595 non-null  int64
#  14  Duration         36595 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 4.2+ MB

# %%
bike_data.dropna(inplace = True)

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36586 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36586 non-null  object
#  1   Time_out         36586 non-null  int64
#  2   Station_no_out   36586 non-null  int64
#  3   Station_out      36586 non-null  object
#  4   Membership_type  36586 non-null  object
#  5   Gender           36586 non-null  object
#  6   Age_Group        36586 non-null  object
#  7   Momentum         36586 non-null  object
#  8   Station_no_in    36586 non-null  int64
#  9   Station_in       36586 non-null  object
#  10  Date_in          36586 non-null  object
#  11  Bike_no          36586 non-null  object
#  12  Carbon_amount    36586 non-null  object
#  13  Distance         36586 non-null  int64
#  14  Duration         36586 non-null  int64
# dtypes: int64(5), object(10)
# memory usage: 4.5+ MB

# %%
bike_data[['Momentum', 'Carbon_amount']].dtypes
# Out:
# Momentum         object
# Carbon_amount    object
# dtype: object

# %%
bike_data[['Momentum', 'Carbon_amount']]= bike_data[['Momentum', 'Carbon_amount']].astype(float)

# %%
bike_data[['Momentum', 'Carbon_amount']].dtypes
# Out:
# Momentum         float64
# Carbon_amount    float64
# dtype: object

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36586 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36586 non-null  object
#  1   Time_out         36586 non-null  int64
#  2   Station_no_out   36586 non-null  int64
#  3   Station_out      36586 non-null  object
#  4   Membership_type  36586 non-null  object
#  5   Gender           36586 non-null  object
#  6   Age_Group        36586 non-null  object
#  7   Momentum         36586 non-null  float64
#  8   Station_no_in    36586 non-null  int64
#  9   Station_in       36586 non-null  object
#  10  Date_in          36586 non-null  object
#  11  Bike_no          36586 non-null  object
#  12  Carbon_amount    36586 non-null  float64
#  13  Distance         36586 non-null  int64
#  14  Duration         36586 non-null  int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 4.5+ MB

# %%
import numpy as np

def outliers_iqr(data):
    q1, q3 = np.percentile(data,[25,75])
    iqr = q3 -q1
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)
    return np.where((data>upper_bound) | (data<lower_bound))

outliers = outliers_iqr(bike_data.Distance)

# %%
np.size(outliers)
# Out:
# 3058

# %%
outliers
# Out:
# (array([   31,    97,   118, ..., 36566, 36572, 36576], dtype=int64),)

# %%
bike_data.iloc[outliers]
# Out:
#          Date_out  Time_out  Station_no_out             Station_out  \
# 31     2019-10-03         0             403            403. 부엉이공원 앞
# 97     2019-10-03         1             181           181. 망원초록길 입구
# 118    2019-10-03         2            2222        2222.사당역 12번출구 뒤
# 163    2019-10-03         2             903         903. 은평뉴타운 아이파크
# 247    2019-10-03         3            2505  2505. 우성아파트사거리 (기업은행앞)
# ...           ...       ...             ...                     ...
# 36564  2019-10-05        23             933          933. LG서비스 역촌점
# 36569  2019-10-05        23             148         148. 용강동 주민센터 앞
# 36575  2019-10-05        23             437           437. 대흥역 1번출구
# 36581  2019-10-05        23             641           641. 용두역 4번출구
# 36585  2019-10-05        23             648           648. 장안동위더스빌옆
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in  \
# 31                정기권      M       40대    483.28            194
# 97                일일권      U       30대    777.43           1328
# 118               정기권      U       30대    549.60           1124
# 163               정기권      M       50대    319.57            184
# 247               일일권      U       30대    373.51           1201
# ...               ...    ...       ...       ...            ...
# 36564             일일권      F       20대    220.41            418
# 36569             일일권      F       30대    335.94            146
# 36575             일일권      M       20대    346.10            437
# 36581             일일권      M       20대    303.22            583
# 36585             일일권      M       30대    824.45            398
#
#             Station_in                 Date_in    Bike_no  Carbon_amount  \
# 31               증산교 앞   2019-10-03 오전 2:03:13  SPB-06112           3.15
# 97            월곡역 3번출구   2019-10-03 오전 3:29:29  SPB-16451           5.69
# 118    발산역 6번출구옆(다이소앞)   2019-10-03 오전 4:03:32  SPB-24365           4.74
# 163       SK망원동주유소 건너편   2019-10-03 오전 5:11:40  SPB-14422           3.12
# 247        가락시장역 3번 출구   2019-10-03 오전 4:49:48  SPB-23456           2.74
# ...                ...                     ...        ...            ...
# 36564   월드컵경기장역 3번출구 옆  2019-10-06 오전 12:29:02  SPB-07222           2.81
# 36569       마포역 2번출구 뒤   2019-10-06 오전 1:05:07  SPB-21082           3.64
# 36575         대흥역 1번출구   2019-10-06 오전 1:26:17  SPB-25415           2.67
# 36581       청계천 생태교실 앞  2019-10-06 오전 12:09:02  SPB-19379           2.73
# 36585      을지로3가역 3번출구  2019-10-06 오전 12:11:27  SPB-22806           7.43
#
#        Distance  Duration
# 31        13560        67
# 97        24540       107
# 118       20410        81
# 163       13450       131
# 247       11790        64
# ...         ...       ...
# 36564     12100        87
# 36569     15710        85
# 36575     11500       109
# 36581     11780        57
# 36585     32030        37
#
# [3058 rows x 15 columns]

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36586 entries, 0 to 36594
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         36586 non-null  object
#  1   Time_out         36586 non-null  int64
#  2   Station_no_out   36586 non-null  int64
#  3   Station_out      36586 non-null  object
#  4   Membership_type  36586 non-null  object
#  5   Gender           36586 non-null  object
#  6   Age_Group        36586 non-null  object
#  7   Momentum         36586 non-null  float64
#  8   Station_no_in    36586 non-null  int64
#  9   Station_in       36586 non-null  object
#  10  Date_in          36586 non-null  object
#  11  Bike_no          36586 non-null  object
#  12  Carbon_amount    36586 non-null  float64
#  13  Distance         36586 non-null  int64
#  14  Duration         36586 non-null  int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 4.5+ MB

# %%
bike_data
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         0             150      150. 서강대역 2번출구 앞
# 2      2019-10-03         0             240       240. 문래역 4번출구 앞
# 3      2019-10-03         0             623       623. 서울시립대 정문 앞
# 4      2019-10-03         0             633       633. 청량리 기업은행 앞
# ...           ...       ...             ...                   ...
# 36590  2019-10-05        23             130  130. 신촌역(2호선) 7번출구 앞
# 36591  2019-10-05        23            2215      2215. 반포종합운동장 입구
# 36592  2019-10-05        23             654         654. 전농동 텃골공원
# 36593  2019-10-05        23             119          119. 서강나루 공원
# 36594  2019-10-05        23             630         630. 동대문구 보건소
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in    Station_in  \
# 0                 정기권      U      ~10대     28.27            122      신성기사식당 앞
# 1                 정기권      U       20대    146.46           2065     서울시여성가족재단
# 2                 정기권      U       20대     37.13            245   삼성생명 당산사옥 앞
# 3                 정기권      U       20대    134.62           1346   길음8골어린이공원 옆
# 4                 정기권      U       20대     85.83            568    청계8가사거리 부근
# ...               ...    ...       ...       ...            ...           ...
# 36590             일일권      M       30대    110.06            432       마포중앙도서관
# 36591             일일권      M       30대    153.15           2221  하나은행 방배동지점 앞
# 36592             일일권      M       40대     65.12            654      전농동 텃골공원
# 36593             일일권      M       40대     78.76           3102         연희삼거리
# 36594             단체권      U       20대     22.83            660        동의보감타워
#
#                       Date_in    Bike_no  Carbon_amount  Distance  Duration
# 0      2019-10-03 오전 12:20:42  SPB-15000           0.24      1050         5
# 1       2019-10-03 오전 1:16:32  SPB-13087           1.32      5690        32
# 2      2019-10-03 오전 12:18:21  SPB-23229           0.29      1250        10
# 3       2019-10-03 오전 1:15:39  SPB-14181           1.21      5230        24
# 4      2019-10-03 오전 12:17:58  SPB-15221           0.67      2890        11
# ...                       ...        ...            ...       ...       ...
# 36590  2019-10-06 오전 12:06:20  SPB-14263           0.90      3860        23
# 36591  2019-10-06 오전 12:27:55  SPB-17557           1.38      5950        32
# 36592  2019-10-06 오전 12:09:12  SPB-18226           0.59      2530        17
# 36593  2019-10-05 오후 11:44:39  SPB-21624           0.71      3060        17
# 36594  2019-10-05 오후 11:27:13  SPB-02538           0.14       620         5
#
# [36586 rows x 15 columns]

# %%
stations = pd.read_csv('data/stations.csv')

# %%
stations
# Out:
#       Gu    ID           Station                  Address   Latitude  \
# 0    마포구   101  101. (구)합정동 주민센터       서울특별시 마포구 동교로8길 58  37.549561
# 1    마포구   102   102. 망원역 1번출구 앞        서울특별시 마포구 월드컵로 72  37.555649
# 2    마포구   103   103. 망원역 2번출구 앞        서울특별시 마포구 월드컵로 79  37.554951
# 3    마포구   104   104. 합정역 1번출구 앞         서울특별시 마포구 양화로 59  37.550629
# 4    마포구   105   105. 합정역 5번출구 앞         서울특별시 마포구 양화로 48  37.550007
# ..   ...   ...               ...                      ...        ...
# 366  서초구  2510              JW타워          서초구 서초동 1748-45  37.483040
# 367  서초구  2511        이수역 6번출구 앞           서초구 방배동 438-35  37.483662
# 368  은평구   972               수색역                  수색로 261  37.582180
# 369  마포구   440           하늘공원 입구          마포구 하늘공원로 108-2  37.570006
# 370  서초구  2265   2265. 이수고가차도 남단  서울특별시 서초구 동작대로 204 청남빌딩  37.494743
#
#       Longitude              Date  No_of_Racks
# 0    126.905754  2015-09-06 23:40            5
# 1    126.910629  2015-09-06 23:42           20
# 2    126.910835  2015-09-06 23:43           14
# 3    126.914986  2015-09-06 23:44           13
# 4    126.914825  2015-09-06 23:45            5
# ..          ...               ...          ...
# 366  127.021461        2019.03.26            8
# 367  126.982323        2019.03.14           20
# 368  126.894943        2019.06.14           20
# 369  126.881149        2019.08.02           15
# 370  126.983063  2017-08-09 11:16           10
#
# [371 rows x 8 columns]

# %%
bike_data2 = pd.merge(bike_data, stations, left_on = 'Station_no_out', right_on = 'ID')

# %%
bike_data2
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             129  129. 신촌역(2호선) 6번출구 옆
# 1      2019-10-03         4             129  129. 신촌역(2호선) 6번출구 옆
# 2      2019-10-03        10             129  129. 신촌역(2호선) 6번출구 옆
# 3      2019-10-03        12             129  129. 신촌역(2호선) 6번출구 옆
# 4      2019-10-03        13             129  129. 신촌역(2호선) 6번출구 옆
# ...           ...       ...             ...                   ...
# 36581  2019-10-05        21             124       124. 서강대 정문 건너편
# 36582  2019-10-05        21             124       124. 서강대 정문 건너편
# 36583  2019-10-05        22             124       124. 서강대 정문 건너편
# 36584  2019-10-05        22             124       124. 서강대 정문 건너편
# 36585  2019-10-05        22             124       124. 서강대 정문 건너편
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in   Station_in  \
# 0                 정기권      U      ~10대     28.27            122     신성기사식당 앞
# 1                 정기권      M       20대      0.00            126     서강대 후문 옆
# 2                 정기권      F       20대     14.41            125     서강대 남문 옆
# 3                 정기권      U       20대     27.75            125     서강대 남문 옆
# 4                 정기권      U       30대     25.26            118  광흥창역 2번출구 앞
# ...               ...    ...       ...       ...            ...          ...
# 36581             정기권      M       30대      4.75            121      마포소방서 앞
# 36582             정기권      M       40대     27.60            126     서강대 후문 옆
# 36583             정기권      M       40대     83.22           3102        연희삼거리
# 36584             일일권      F       30대     33.32            124   서강대 정문 건너편
# 36585             일일권      M       30대     51.70            124   서강대 정문 건너편
#
#        ... Distance Duration   Gu   ID               Station  \
# 0      ...     1050        5  마포구  129  129. 신촌역(2호선) 6번출구 옆
# 1      ...        0        4  마포구  129  129. 신촌역(2호선) 6번출구 옆
# 2      ...      560        3  마포구  129  129. 신촌역(2호선) 6번출구 옆
# 3      ...      960       62  마포구  129  129. 신촌역(2호선) 6번출구 옆
# 4      ...     1160       10  마포구  129  129. 신촌역(2호선) 6번출구 옆
# ...    ...      ...      ...  ...  ...                   ...
# 36581  ...      200        3  마포구  124       124. 서강대 정문 건너편
# 36582  ...      820        5  마포구  124       124. 서강대 정문 건너편
# 36583  ...     2840       11  마포구  124       124. 서강대 정문 건너편
# 36584  ...     1870       27  마포구  124       124. 서강대 정문 건너편
# 36585  ...     1920       23  마포구  124       124. 서강대 정문 건너편
#
#                    Address   Latitude   Longitude              Date  \
# 0        서울특별시 마포구 신촌로 106  37.555054  126.937569  2015-09-07 10:37
# 1        서울특별시 마포구 신촌로 106  37.555054  126.937569  2015-09-07 10:37
# 2        서울특별시 마포구 신촌로 106  37.555054  126.937569  2015-09-07 10:37
# 3        서울특별시 마포구 신촌로 106  37.555054  126.937569  2015-09-07 10:37
# 4        서울특별시 마포구 신촌로 106  37.555054  126.937569  2015-09-07 10:37
# ...                    ...        ...         ...               ...
# 36581  서울특별시 마포구 서강로16길 72  37.551140  126.936989  2015-09-07 10:33
# 36582  서울특별시 마포구 서강로16길 72  37.551140  126.936989  2015-09-07 10:33
# 36583  서울특별시 마포구 서강로16길 72  37.551140  126.936989  2015-09-07 10:33
# 36584  서울특별시 마포구 서강로16길 72  37.551140  126.936989  2015-09-07 10:33
# 36585  서울특별시 마포구 서강로16길 72  37.551140  126.936989  2015-09-07 10:33
#
#        No_of_Racks
# 0               15
# 1               15
# 2               15
# 3               15
# 4               15
# ...            ...
# 36581           20
# 36582           20
# 36583           20
# 36584           20
# 36585           20
#
# [36586 rows x 23 columns]

# %%
import pandas as pd

df1 = pd.DataFrame({'a':['a','b','c'], 'b':[1,2,3]})

# %%
df1
# Out:
#    a  b
# 0  a  1
# 1  b  2
# 2  c  3

# %%
df2 = pd.DataFrame({'a':['a','b','d'], 'c':['가', '나', '다']})

# %%
df2
# Out:
#    a  c
# 0  a  가
# 1  b  나
# 2  d  다

# %%
pd.merge(df1, df2, how='inner', on = 'a')
# Out:
#    a  b  c
# 0  a  1  가
# 1  b  2  나

# %%
pd.merge(df1, df2, how='outer', on = 'a')
# Out:
#    a    b    c
# 0  a  1.0    가
# 1  b  2.0    나
# 2  c  3.0  NaN
# 3  d  NaN    다

# %%
pd.merge(df1, df2, how='left', on = 'a')
# Out:
#    a  b    c
# 0  a  1    가
# 1  b  2    나
# 2  c  3  NaN

# %%
pd.merge(df1, df2, how='right', on = 'a')
# Out:
#    a    b  c
# 0  a  1.0  가
# 1  b  2.0  나
# 2  d  NaN  다

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = bike_data2.Gender.unique()
sizes = bike_data2.Gender.value_counts()
colors = ['yellowgreen','lightskyblue','lightcoral','blue','coral']
plt.pie(sizes, labels = labels, colors = colors, autopct = '%1.1f%%', startangle = 90)
plt.show()

# %%
plt.hist(bike_data2.Distance, color = 'blue')
plt.show()

# %%
plt.hist(bike_data2.Distance, color = 'blue', bins = 1000)
plt.show()

# %%
plt.boxplot(bike_data2.Distance)
plt.show()

# %%
under_5000 = bike_data2[bike_data2.Distance < 5000]
plt.boxplot(under_5000.Distance)
plt.show()

# %%
under_5000 = bike_data2[bike_data2.Distance < 5000]
plt.boxplot([under_5000.Distance[under_5000.Gender=='F'], under_5000.Distance[under_5000.Gender =='M']])
plt.xticks([1,2],['Female','Male'])
plt.show()

# %%
plt.plot(bike_data['Distance'].groupby(bike_data['Date_out']).sum())
plt.show()

# %%
plt.bar(labels, height=sizes, color = 'blue')
plt.show()

# %%
bike_data2['Gender'].value_counts().plot(kind = 'bar')
plt.show()

# %%
bike_data2.Gender.value_counts()
# Out:
# U    18330
# M    11023
# F     7215
# m       14
# f        4
# Name: Gender, dtype: int64

# %%
bike_data2[bike_data2.Gender == 'f']
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 17878  2019-10-04        13             205           205. 산업은행 앞
# 18410  2019-10-04        17            2252         2252. 하이브랜드 앞
# 21751  2019-10-05        18            2251  2251. 더케이호텔 입구(양재2)
# 23310  2019-10-05        15             152       152. 마포구민체육센터 앞
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in  \
# 17878             일일권      f       20대    156.29           1834
# 18410             정기권      f       20대     63.84           2243
# 21751             정기권      f       40대     40.51           2243
# 23310             일일권      f       30대    132.07            106
#
#            Station_in  ... Distance Duration    Gu    ID  \
# 17878  월드메르디앙 벤처센터 2차  ...     7590       59  영등포구   205
# 18410          서울가정법원  ...     2480       13   서초구  2252
# 21751          서울가정법원  ...     1930       11   서초구  2251
# 23310      합정역 7번출구 앞  ...     6670      113   마포구   152
#
#                     Station               Address   Latitude   Longitude  \
# 17878           205. 산업은행 앞   서울특별시 영등포구 의사당대로 97  37.526264  126.920509
# 18410         2252. 하이브랜드 앞      서울특별시 서초구 매헌로 16  37.463322  127.036041
# 21751  2251. 더케이호텔 입구(양재2)   서울특별시 서초구 바우뫼로12길 70  37.467506  127.034477
# 23310       152. 마포구민체육센터 앞   서울특별시 마포구 망원동 452-4  37.556610  126.898018
#
#                    Date  No_of_Racks
# 17878  2015-09-17 15:08           20
# 18410   2017-06-24 9:58           25
# 21751   2017-06-13 9:35           10
# 23310  2016-06-29 12:00           30
#
# [4 rows x 23 columns]

# %%
bike_data2.loc[bike_data2.Gender == 'f', 'Gender'] = 'F'

# %%
bike_data2[bike_data2.Gender == 'f']
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration, Gu, ID, Station, Address, Latitude, Longitude, Date, No_of_Racks]
# Index: []
#
# [0 rows x 23 columns]

# %%
bike_data2[bike_data2.Gender == 'm']
# Out:
#          Date_out  Time_out  Station_no_out              Station_out  \
# 1194   2019-10-05        23             212         212. 여의도역 1번출구 옆
# 4444   2019-10-04         9             237        237. 보라매 두산위브 건너편
# 5881   2019-10-03        23             113        113. 홍대입구역 2번출구 앞
# 12864  2019-10-05        18             279        279. 영등포 푸르지오 아파트
# 15742  2019-10-04        17             220          220. 미성아파트 A동 앞
# 16038  2019-10-05        23             207        207. 여의나루역 1번출구 앞
# 16125  2019-10-04        19            2231  2231. 삼성타운(삼성생명) A동 맞은편
# 16289  2019-10-03        17             257         257. 신길삼거리(우리은행)
# 16296  2019-10-03        19             257         257. 신길삼거리(우리은행)
# 16406  2019-10-05        22             257         257. 신길삼거리(우리은행)
# 18032  2019-10-03        19             961           961. 불광역 9번 출구
# 19598  2019-10-04        21             143            143. 공덕역 2번출구
# 23590  2019-10-05        22             259             259. 대방역6번출구
# 34889  2019-10-04        14             641            641. 용두역 4번출구
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in    Station_in  \
# 1194              정기권      m      ~10대     30.92            257   신길삼거리(우리은행)
# 4444              일일권      m       20대     77.55           2136      신림역 8번출구
# 5881              일일권      m       20대     96.30            166      가재울 초등학교
# 12864             정기권      m      ~10대     39.79           1961    신도림테크노근린공원
# 15742             정기권      m      ~10대     43.59            257   신길삼거리(우리은행)
# 16038             정기권      m      ~10대    189.57            212   여의도역 1번출구 옆
# 16125             일일권      m       20대     41.58           2369        KT선릉타워
# 16289             정기권      m      ~10대     46.63            279  영등포 푸르지오 아파트
# 16296             정기권      m       30대     52.67            292      영일 어린이공원
# 16406             정기권      m      ~10대     41.06            211   여의도역 4번출구 옆
# 18032             정기권      m       20대    221.54            419        홈플러스 앞
# 19598             정기권      m       30대     76.63            805     문배어린이공원 앞
# 23590             정기권      m      ~10대     62.09            207  여의나루역 1번출구 앞
# 34889             정기권      m       50대    328.94            583    청계천 생태교실 앞
#
#        ... Distance Duration    Gu    ID                  Station  \
# 1194   ...     1220        8  영등포구   212         212. 여의도역 1번출구 옆
# 4444   ...     3060       14  영등포구   237        237. 보라매 두산위브 건너편
# 5881   ...     2930       15   마포구   113        113. 홍대입구역 2번출구 앞
# 12864  ...     1570        8  영등포구   279        279. 영등포 푸르지오 아파트
# 15742  ...     1720       13  영등포구   220          220. 미성아파트 A동 앞
# 16038  ...     7480       49  영등포구   207        207. 여의나루역 1번출구 앞
# 16125  ...     1750       32   서초구  2231  2231. 삼성타운(삼성생명) A동 맞은편
# 16289  ...     1840       11  영등포구   257         257. 신길삼거리(우리은행)
# 16296  ...     1750       11  영등포구   257         257. 신길삼거리(우리은행)
# 16406  ...     1620       14  영등포구   257         257. 신길삼거리(우리은행)
# 18032  ...     6660       39   은평구   961                불광역 9번 출구
# 19598  ...     2250       49   마포구   143            143. 공덕역 2번출구
# 23590  ...     2450       16  영등포구   259             259. 대방역6번출구
# 34889  ...    10130       56  동대문구   641            641. 용두역 4번출구
#
#                      Address   Latitude   Longitude              Date  \
# 1194     서울특별시 영등포구 의사당대로 88  37.521362  126.923462  2015-09-17 15:12
# 4444    서울특별시 영등포구 신길동 4490   37.496513  126.914803  2016-06-29 12:00
# 5881       서울특별시 마포구 양화로 165  37.557499  126.923805   2015-09-07 1:32
# 12864   서울특별시 영등포구 도신로29길 28  37.513229  126.904465  2017-12-22 14:36
# 15742   서울특별시 영등포구 의사당대로 110  37.519363  126.926048  2015-09-17 15:18
# 16038  서울특별시 영등포구 여의동로 지하343  37.526989  126.932098  2015-09-17 15:33
# 16125     서울특별시 서초구 서초대로 405  37.496914  127.024963  2017-06-01 10:32
# 16289   서울특별시 영등포구 신길동95-256  37.513844  126.919357  2016-06-29 12:00
# 16296   서울특별시 영등포구 신길동95-256  37.513844  126.919357  2016-06-29 12:00
# 16406   서울특별시 영등포구 신길동95-256  37.513844  126.919357  2016-06-29 12:00
# 18032            불광동 281-109  37.610970  126.929810        2018.10.18
# 19598   서울특별시 마포구 공덕동 257-88  37.544579  126.950218  2016-06-29 12:00
# 23590     서울특별시 영등포구 신길동1368  37.513592  126.925934  2016-06-29 12:00
# 34889    서울특별시 동대문구 청계천로 563  37.573753  127.038536  2016-07-06 12:00
#
#        No_of_Racks
# 1194            35
# 4444            20
# 5881            25
# 12864           15
# 15742           30
# 16038           40
# 16125           15
# 16289           10
# 16296           10
# 16406           10
# 18032            8
# 19598            9
# 23590           17
# 34889           10
#
# [14 rows x 23 columns]

# %%
bike_data2.loc[bike_data2.Gender == 'm', 'Gender'] = 'M'

# %%
bike_data2[bike_data2.Gender == 'm']
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration, Gu, ID, Station, Address, Latitude, Longitude, Date, No_of_Racks]
# Index: []
#
# [0 rows x 23 columns]

# %%
bike_data2.Gender.value_counts()
# Out:
# U    18330
# M    11037
# F     7219
# Name: Gender, dtype: int64

# %%
bike_data2[bike_data2.Distance == 0]
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 1      2019-10-03         4             129  129. 신촌역(2호선) 6번출구 옆
# 21     2019-10-03        18             129  129. 신촌역(2호선) 6번출구 옆
# 27     2019-10-03        20             129  129. 신촌역(2호선) 6번출구 옆
# 79     2019-10-04        21             129  129. 신촌역(2호선) 6번출구 옆
# 165    2019-10-04         7             150      150. 서강대역 2번출구 앞
# ...           ...       ...             ...                   ...
# 36378  2019-10-05        15            2201       2201. 본마을 정류소 앞
# 36426  2019-10-04        18            2257   2257. 하나로클럽 양재점 맞은편
# 36473  2019-10-04        21            2249      2249. 우솔초등학교 맞은편
# 36497  2019-10-05        20            2510            2510. JW타워
# 36519  2019-10-04        12             124       124. 서강대 정문 건너편
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in  \
# 1                 정기권      M       20대       0.0            126
# 21                정기권      M       30대       0.0            129
# 27                정기권      M       20대       0.0            126
# 79                일일권      U      ~10대       0.0            437
# 165               정기권      U       30대       0.0            143
# ...               ...    ...       ...       ...            ...
# 36378             일일권      U       30대       0.0           2351
# 36426             정기권      U       40대       0.0           2618
# 36473             일일권      M       40대       0.0           2335
# 36497             정기권      U       40대       0.0           2249
# 36519             정기권      M       20대       0.0            437
#
#             Station_in  ... Distance Duration   Gu    ID  \
# 1             서강대 후문 옆  ...        0        4  마포구   129
# 21     신촌역(2호선) 6번출구 옆  ...        0        2  마포구   129
# 27            서강대 후문 옆  ...        0        4  마포구   129
# 79            대흥역 1번출구  ...        0       26  마포구   129
# 165           공덕역 2번출구  ...        0       10  마포구   150
# ...                ...  ...      ...      ...  ...   ...
# 36378     청소년수련관(수영장)앞  ...        0       63  서초구  2201
# 36426         삼전역 1번출구  ...        0       40  서초구  2257
# 36473    3호선 매봉역 3번출구앞  ...        0       24  서초구  2249
# 36497       우솔초등학교 맞은편  ...        0       20  서초구  2510
# 36519         대흥역 1번출구  ...        0        2  마포구   124
#
#                     Station                Address   Latitude   Longitude  \
# 1      129. 신촌역(2호선) 6번출구 옆      서울특별시 마포구 신촌로 106  37.555054  126.937569
# 21     129. 신촌역(2호선) 6번출구 옆      서울특별시 마포구 신촌로 106  37.555054  126.937569
# 27     129. 신촌역(2호선) 6번출구 옆      서울특별시 마포구 신촌로 106  37.555054  126.937569
# 79     129. 신촌역(2호선) 6번출구 옆      서울특별시 마포구 신촌로 106  37.555054  126.937569
# 165        150. 서강대역 2번출구 앞  서울특별시 마포구 노고산동 112-13  37.552956  126.934341
# ...                     ...                    ...        ...         ...
# 36378       2201. 본마을 정류소 앞      서울특별시 서초구 본마을2길 2  37.453281  127.051483
# 36426   2257. 하나로클럽 양재점 맞은편      서울특별시 서초구 청계산로 10  37.462688  127.046112
# 36473      2249. 우솔초등학교 맞은편    서울특별시 서초구 양재대로2길 74  37.456234  127.019348
# 36497                  JW타워        서초구 서초동 1748-45  37.483040  127.021461
# 36519       124. 서강대 정문 건너편    서울특별시 마포구 서강로16길 72  37.551140  126.936989
#
#                    Date  No_of_Racks
# 1      2015-09-07 10:37           15
# 21     2015-09-07 10:37           15
# 27     2015-09-07 10:37           15
# 79     2015-09-07 10:37           15
# 165    2016-06-29 12:00           15
# ...                 ...          ...
# 36378   2017-06-01 9:57           20
# 36426  2017-06-01 10:48           10
# 36473  2017-06-22 13:56           10
# 36497        2019.03.26            8
# 36519  2015-09-07 10:33           20
#
# [1005 rows x 23 columns]

# %%
bike_data2.loc[bike_data2.Distance == 0, 'Duration'].max()
# Out:
# 214

# %%
bike_data2 = bike_data2[bike_data2.Distance != 0]

# %%
bike_data2[bike_data2.Distance == 0]
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration, Gu, ID, Station, Address, Latitude, Longitude, Date, No_of_Racks]
# Index: []
#
# [0 rows x 23 columns]

# %%
bike_data2[bike_data2.Duration == 0]
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Station_no_out, Station_out, Membership_type, Gender, Age_Group, Momentum, Station_no_in, Station_in, Date_in, Bike_no, Carbon_amount, Distance, Duration, Gu, ID, Station, Address, Latitude, Longitude, Date, No_of_Racks]
# Index: []
#
# [0 rows x 23 columns]

# %%
bike_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35581 entries, 0 to 36585
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date_out         35581 non-null  object
#  1   Time_out         35581 non-null  int64
#  2   Station_no_out   35581 non-null  int64
#  3   Station_out      35581 non-null  object
#  4   Membership_type  35581 non-null  object
#  5   Gender           35581 non-null  object
#  6   Age_Group        35581 non-null  object
#  7   Momentum         35581 non-null  float64
#  8   Station_no_in    35581 non-null  int64
#  9   Station_in       35581 non-null  object
#  10  Date_in          35581 non-null  object
#  11  Bike_no          35581 non-null  object
#  12  Carbon_amount    35581 non-null  float64
#  13  Distance         35581 non-null  int64
#  14  Duration         35581 non-null  int64
#  15  Gu               35581 non-null  object
#  16  ID               35581 non-null  int64
#  17  Station          35581 non-null  object
#  18  Address          35581 non-null  object
#  19  Latitude         35581 non-null  float64
#  20  Longitude        35581 non-null  float64
#  21  Date             35581 non-null  object
#  22  No_of_Racks      35581 non-null  int64
# dtypes: float64(4), int64(7), object(12)
# memory usage: 6.5+ MB

# %%
import pandas as pd
bike_data = pd.read_csv('data/bike_usage_0.csv', encoding = 'ANSI')
weather = pd.read_csv('data\weather.csv')

# 공백 제거
import numpy as np
bike_data.loc[bike_data.Momentum == '\\N', 'Momentum'] = np.nan
bike_data.dropna(inplace = True)

# 수치형 변경
bike_data[['Momentum', 'Carbon_amount']]= bike_data[['Momentum', 'Carbon_amount']].astype(float)

import numpy as np

def outliers_iqr(data):
    q1, q3 = np.percentile(data,[25,75])
    iqr = q3 -q1
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)
    return np.where((data>upper_bound) | (data<lower_bound))

# outlier 제거
outliers = outliers_iqr(bike_data.Distance)

stations = pd.read_csv('data/stations.csv')

# database 병합
bike_data2 = pd.merge(bike_data, stations, left_on = 'Station_no_out', right_on = 'ID')

# 이상치 처리
bike_data2.loc[bike_data2.Gender == 'f', 'Gender'] = 'F'
bike_data2.loc[bike_data2.Gender == 'm', 'Gender'] = 'M'
bike_data2 = bike_data2[bike_data2.Distance != 0]

# %%
pd.pivot_table(bike_data2, index='Age_Group', columns='Membership_type', values='Distance')
# Out:
# Membership_type          단체권          일일권  일일권(비회원)          정기권
# Age_Group
# 20대              4549.333333  5617.097561    7080.0  3390.363565
# 30대              3716.923077  6711.776605       NaN  3714.835600
# 40대              5065.000000  6661.860465       NaN  3996.754123
# 50대              2200.000000  7887.666667       NaN  3922.459930
# 60대                      NaN  6583.200000       NaN  4118.870192
# 70대~             2450.000000  9512.500000       NaN  3638.372093
# ~10대             1990.000000  5690.655738       NaN  2924.400000

# %%
bike_pivot = pd.pivot_table(bike_data2, index='Age_Group', columns='Membership_type', values='Distance', aggfunc=np.sum)

# %%
bike_pivot
# Out:
# Membership_type      단체권         일일권  일일권(비회원)         정기권
# Age_Group
# 20대              68240.0  11515050.0   14160.0  17345100.0
# 30대              48320.0   7631290.0       NaN  15026510.0
# 40대              50650.0   2864600.0       NaN  10663340.0
# 50대               4400.0    709890.0       NaN   5628730.0
# 60대                  NaN    164580.0       NaN   1713450.0
# 70대~              2450.0     38050.0       NaN    469350.0
# ~10대              3980.0    347130.0       NaN    365550.0

# %%
pd.melt(bike_pivot, id_vars='Age_Group', value_vars = ['단체권', '일일권', '일일권(비회원)', '정기권'], var_name='Membership_type', value_name='Total_Dist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'Age_Group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-197-c374267e3513> in <module>
# ----> 1 pd.melt(bike_pivot, id_vars='Age_Group', value_vars = ['단체권', '일일권', '일일권(비회원)', '정기권'], var_name='Membership_type', value_name='Total_Dist')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     117     mdata = {}
#     118     for col in id_vars:
# --> 119         id_data = frame.pop(col)
#     120         if is_extension_array_dtype(id_data):
#     121             id_data = cast("Series", concat([id_data] * K, ignore_index=True))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4510         3  monkey        NaN
#    4511         """
# -> 4512         return super().pop(item=item)
#    4513
#    4514     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     767
#     768     def pop(self, item: Label) -> Union[Series, Any]:
# --> 769         result = self[item]
#     770         del self[item]
#     771         if self.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Age_Group'

# %%
import matplotlib.pyplot as plt
import numpy as np

random_sample = np.random.normal(loc=10, scale=2, size=1000)
plt.hist(random_sample, bins=100)
plt.show()

# %%
import numpy as np
import pylab
import scipy.stats as stats

norm_sample = np.random.normal(loc=20, scale=5, size=100)
stats.probplot(norm_sample, dist='norm', plot=pylab)
pylab.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

avg_values = []
for i in range(1,11):
    random_sample = random.sample(range(1, 1000), 100)
    x = np.mean(random_sample)
    avg_values.append(x)
    
plt.hist(avg_values, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

avg_values = []
for i in range(1,101):
    random_sample = random.sample(range(1, 1000), 100)
    x = np.mean(random_sample)
    avg_values.append(x)
    
plt.hist(avg_values, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

avg_values = []
for i in range(1,1001):
    random_sample = random.sample(range(1, 1000), 100)
    x = np.mean(random_sample)
    avg_values.append(x)
    
plt.hist(avg_values, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

avg_values = []
for i in range(1,10001):
    random_sample = random.sample(range(1, 1000), 100)
    x = np.mean(random_sample)
    avg_values.append(x)
    
plt.hist(avg_values, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bike_data2
# Out:
#          Date_out  Time_out  Station_no_out           Station_out  \
# 0      2019-10-03         0             130  130. 신촌역(2호선) 7번출구 앞
# 1      2019-10-03        10             130  130. 신촌역(2호선) 7번출구 앞
# 2      2019-10-03        11             130  130. 신촌역(2호선) 7번출구 앞
# 3      2019-10-03        14             130  130. 신촌역(2호선) 7번출구 앞
# 4      2019-10-03        15             130  130. 신촌역(2호선) 7번출구 앞
# ...           ...       ...             ...                   ...
# 18251  2019-10-04        10            2275      2275. 염곡치안센터 건너편
# 18252  2019-10-04        18            2275      2275. 염곡치안센터 건너편
# 18253  2019-10-05         2            2275      2275. 염곡치안센터 건너편
# 18254  2019-10-05        11            2275      2275. 염곡치안센터 건너편
# 18255  2019-10-05        11            2275      2275. 염곡치안센터 건너편
#
#       Membership_type Gender Age_Group  Momentum  Station_no_in  \
# 0                 정기권      M       20대     33.46            119
# 1                 정기권      M       50대      9.02            150
# 2                 정기권      F       20대     40.63            111
# 3                 일일권      F       20대    299.08            130
# 4                 정기권      F       20대     57.14           3102
# ...               ...    ...       ...       ...            ...
# 18251             정기권      M       50대     51.64           2288
# 18252             정기권      M       30대    374.77           2307
# 18253             정기권      M       50대     58.49           2203
# 18254             일일권      F       40대    379.89           2259
# 18255             단체권      F       40대    376.22           2259
#
#             Station_in  ... Distance Duration   Gu    ID  \
# 0              서강나루 공원  ...     1300        5  마포구   130
# 1          서강대역 2번출구 앞  ...      340        3  마포구   130
# 2           상수역 2번출구 앞  ...     1710       11  마포구   130
# 3      신촌역(2호선) 7번출구 앞  ...    14250      108  마포구   130
# 4                연희삼거리  ...     2220       16  마포구   130
# ...                ...  ...      ...      ...  ...   ...
# 18251           안골마을입구  ...     1630       14  서초구  2275
# 18252    압구정 한양 3차 아파트  ...    13520       39  서초구  2275
# 18253      청계산입구역 2번출구  ...     2110       13  서초구  2275
# 18254   잠원역 3번-4번 출구사이  ...    16540      141  서초구  2275
# 18255   잠원역 3번-4번 출구사이  ...    16380      121  서초구  2275
#
#                     Station           Address   Latitude   Longitude  \
# 0      130. 신촌역(2호선) 7번출구 앞  서울특별시 마포구 신촌로 94  37.554859  126.936157
# 1      130. 신촌역(2호선) 7번출구 앞  서울특별시 마포구 신촌로 94  37.554859  126.936157
# 2      130. 신촌역(2호선) 7번출구 앞  서울특별시 마포구 신촌로 94  37.554859  126.936157
# 3      130. 신촌역(2호선) 7번출구 앞  서울특별시 마포구 신촌로 94  37.554859  126.936157
# 4      130. 신촌역(2호선) 7번출구 앞  서울특별시 마포구 신촌로 94  37.554859  126.936157
# ...                     ...               ...        ...         ...
# 18251      2275. 염곡치안센터 건너편   서울특별시 염곡동 260-1  37.461578  127.048798
# 18252      2275. 염곡치안센터 건너편   서울특별시 염곡동 260-1  37.461578  127.048798
# 18253      2275. 염곡치안센터 건너편   서울특별시 염곡동 260-1  37.461578  127.048798
# 18254      2275. 염곡치안센터 건너편   서울특별시 염곡동 260-1  37.461578  127.048798
# 18255      2275. 염곡치안센터 건너편   서울특별시 염곡동 260-1  37.461578  127.048798
#
#                    Date  No_of_Racks
# 0      2015-09-07 10:37           10
# 1      2015-09-07 10:37           10
# 2      2015-09-07 10:37           10
# 3      2015-09-07 10:37           10
# 4      2015-09-07 10:37           10
# ...                 ...          ...
# 18251  2017-11-01 16:00           10
# 18252  2017-11-01 16:00           10
# 18253  2017-11-01 16:00           10
# 18254  2017-11-01 16:00           10
# 18255  2017-11-01 16:00           10
#
# [17776 rows x 23 columns]

# %%
bike_data2.Gu.value_counts()
# Out:
# 영등포구    5171
# 마포구     5113
# 서초구     2956
# 동대문구    2335
# 은평구     2201
# Name: Gu, dtype: int64

# %%
y_gu = bike_data2[bike_data2.Gu == '영등포구']
m_gu = bike_data2[bike_data2.Gu == '마포구']

# %%
from scipy import stats

stats.levene(y_gu.Distance, m_gu.Distance)
# Out:
# LeveneResult(statistic=0.758025643859691, pvalue=0.38396742567744446)

# %%
np.mean(y_gu.Distance)
# Out:
# 4171.616708567009

# %%
np.mean(m_gu.Distance)
# Out:
# 4226.4912966946995

# %%
stats.ttest_ind(y_gu.Distance, m_gu.Distance, equal_var = True)
# Out:
# Ttest_indResult(statistic=-0.5206285453700429, pvalue=0.6026367706051952)

# %%
s_gu = bike_data2[bike_data2.Gu == '서초구']
d_gu = bike_data2[bike_data2.Gu == '동대문구']
e_gu = bike_data2[bike_data2.Gu == '은평구']

# %%
from scipy import stats

stats.bartlett(y_gu.Distance, m_gu.Distance, s_gu.Distance, d_gu.Distance, e_gu.Distance)
# Out:
# BartlettResult(statistic=168.47196781461724, pvalue=2.2253585272614517e-35)

# %%
stats.f_oneway(y_gu.Distance, m_gu.Distance, s_gu.Distance, d_gu.Distance, e_gu.Distance)
# Out:
# F_onewayResult(statistic=15.329471362155916, pvalue=1.6104855060516996e-12)

# %%
plot_data = [y_gu.Distance, m_gu.Distance, s_gu.Distance, d_gu.Distance, e_gu.Distance]
plt.boxplot(plot_data, showfliers = False)
plt.show()

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

hsd = pairwise_tukeyhsd(bike_data2.Distance, bike_data2.Gu)
hsd.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from scipy.stats import chi2_contingency

crosstab = pd.crosstab(bike_data2.Age_Group, bike_data2.Membership_type)
chi2_contingency(crosstab)
# Out:
# (662.5859653399241,
#  4.875801675742656e-129,
#  18,
#  array([[1.73756188e+01, 1.53430755e+03, 8.08168317e-01, 5.63050866e+03],
#         [1.25666629e+01, 1.10966556e+03, 5.84495950e-01, 4.07218328e+03],
#         [7.51822682e+00, 6.63876913e+02, 3.49684968e-01, 2.43625518e+03],
#         [3.69380063e+00, 3.26171186e+02, 1.71804680e-01, 1.19696321e+03],
#         [1.06677543e+00, 9.41987511e+01, 4.96174617e-02, 3.45684856e+02],
#         [3.24144914e-01, 2.86227498e+01, 1.50765077e-02, 1.05038029e+02],
#         [4.54770477e-01, 4.01572907e+01, 2.11521152e-02, 1.47366787e+02]]))

# %%
result = chi2_contingency(crosstab)
print('Chi2 Statistic : {}, p-value : {}'.format(result[0], result[1]))
# Out:
# Chi2 Statistic : 662.5859653399241, p-value : 4.875801675742656e-129

# %%
dist_by_gu = pd.pivot_table(bike_data2, index = 'Gu', values = 'Distance', aggfunc = len)
dist_by_gu
# Out:
#       Distance
# Gu
# 동대문구      2335
# 마포구       5113
# 서초구       2956
# 영등포구      5171
# 은평구       2201

# %%
population = pd.read_csv('data/population_by_Gu.txt', sep = '\t')
population

# %%
# inner join
by_gu = pd.merge(dist_by_gu, population, on = 'Gu')

# %%
by_gu

# %%
plt.scatter(by_gu.Distance, by_gu.Population)
plt.show()

# %%
stats.pearsonr(by_gu.Distance, by_gu.Population)

# %%
by_gu = pd.merge(dist_by_gu, population, on = 'Gu')[['Gu', 'Distance', 'Population']]
by_gu.corr()

# %%
import pandas as pd
bike_data = pd.read_csv('data/bike_usage_0.csv', encoding = 'ANSI')
weather = pd.read_csv('data\weather.csv')

# 공백 제거
import numpy as np
bike_data.loc[bike_data.Momentum == '\\N', 'Momentum'] = np.nan
bike_data.dropna(inplace = True)

# 수치형 변경
bike_data[['Momentum', 'Carbon_amount']]= bike_data[['Momentum', 'Carbon_amount']].astype(float)

import numpy as np

def outliers_iqr(data):
    q1, q3 = np.percentile(data,[25,75])
    iqr = q3 -q1
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)
    return np.where((data>upper_bound) | (data<lower_bound))

# outlier 제거
outliers = outliers_iqr(bike_data.Distance)

stations = pd.read_csv('data/stations.csv')

# database 병합
bike_data2 = pd.merge(bike_data, stations, left_on = 'Station_no_out', right_on = 'ID')

# 이상치 처리
bike_data2.loc[bike_data2.Gender == 'f', 'Gender'] = 'F'
bike_data2.loc[bike_data2.Gender == 'm', 'Gender'] = 'M'
bike_data2 = bike_data2[bike_data2.Distance != 0]

# 회귀분석 -전처리
new_weather = pd.pivot_table(weather, index = ['date', 'time'], values = ['temp','cum_precipitation', 'humidity', 'insolation', 'sunshine', 'wind', 'wind_direction', 'sea_lvl_pressure', 'pressure'], aggfunc = np.mean)
new_weather = new_weather.reset_index()

new_bike = pd.pivot_table(bike_data2, index = ['Date_out', 'Time_out'], values = ['Distance'], aggfunc = len)
new_bike = new_bike.reset_index()

new_bike.rename(columns = {'Distance':'Count'}, inplace = True)

bike_weather = pd.merge(new_bike, new_weather, left_on = ['Date_out', 'Time_out'], right_on = ['date', 'time'])

# %%
new_weather.columns
# Out:
# Index(['date', 'time', 'cum_precipitation', 'humidity', 'insolation',
#        'pressure', 'sea_lvl_pressure', 'sunshine', 'temp', 'wind',
#        'wind_direction'],
#       dtype='object')

# %%
new_bike.columns
# Out:
# Index(['Date_out', 'Time_out', 'Count'], dtype='object')

# %%
bike_weather
# Out:
#       Date_out  Time_out  Count        date  time  cum_precipitation  \
# 0   2019-10-03         1     22  2019-10-03     1           2.361667
# 1   2019-10-03         2     34  2019-10-03     2           3.353333
# 2   2019-10-03         3     32  2019-10-03     3           3.930000
# 3   2019-10-03         4     24  2019-10-03     4           4.423333
# 4   2019-10-03         5     24  2019-10-03     5           4.500000
# ..         ...       ...    ...         ...   ...                ...
# 64  2019-10-05        19    341  2019-10-05    19           0.600000
# 65  2019-10-05        20    311  2019-10-05    20           0.600000
# 66  2019-10-05        21    356  2019-10-05    21           0.600000
# 67  2019-10-05        22    318  2019-10-05    22           0.600000
# 68  2019-10-05        23    211  2019-10-05    23           0.600000
#
#      humidity  insolation     pressure  sea_lvl_pressure  sunshine       temp  \
# 0   93.846667        0.00   993.010000       1002.910000         0  20.016667
# 1   93.453333        0.00   992.668333       1002.568333         0  19.908333
# 2   91.686667        0.00   992.253333       1002.153333         0  19.923333
# 3   93.061667        0.00   992.316667       1002.216667         0  19.928333
# 4   95.028333        0.00   992.835000       1002.735000         0  19.871667
# ..        ...         ...          ...               ...       ...        ...
# 64  60.570000        8.24  1008.340000       1018.440000      8400  17.171667
# 65  61.381667        8.24  1009.146667       1019.273333      8400  16.610000
# 66  62.598333        8.24  1009.773333       1019.973333      8400  15.988333
# 67  63.560000        8.24  1010.376667       1020.576667      8400  15.436667
# 68  63.426667        8.24  1010.846667       1021.085000      8400  14.986667
#
#         wind  wind_direction
# 0   3.290000      178.788333
# 1   3.056667      333.400000
# 2   2.125000      330.110000
# 3   1.931667      251.535000
# 4   2.886667      236.116667
# ..       ...             ...
# 64  4.085000      146.493333
# 65  3.631667      125.785000
# 66  3.686667      225.700000
# 67  3.680000      225.253333
# 68  3.401667      179.688333
#
# [69 rows x 14 columns]

# %%
type(bike_weather)
# Out:
# pandas.core.frame.DataFrame

# %%
bike_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 0 to 68
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_out           69 non-null     object
#  1   Time_out           69 non-null     int64
#  2   Count              69 non-null     int64
#  3   date               69 non-null     object
#  4   time               69 non-null     int64
#  5   cum_precipitation  69 non-null     float64
#  6   humidity           69 non-null     float64
#  7   insolation         69 non-null     float64
#  8   pressure           69 non-null     float64
#  9   sea_lvl_pressure   69 non-null     float64
#  10  sunshine           69 non-null     int64
#  11  temp               69 non-null     float64
#  12  wind               69 non-null     float64
#  13  wind_direction     69 non-null     float64
#  14  Rain_YN            69 non-null     object
#  15  N                  69 non-null     uint8
#  16  Y                  69 non-null     uint8
#  17  over_500           69 non-null     int64
# dtypes: float64(8), int64(5), object(3), uint8(2)
# memory usage: 9.3+ KB

# %%
bike_weather.shape
# Out:
# (69, 18)

# %%
from scipy import stats

stats.linregress(bike_weather.temp, bike_weather.Count)

# %%
slop, intercept, r_value, p_value, std_err = stats.Iinregress(bike_weather.temp, bike_weather.Count)
print("R-squared : %f" %r_value**2)

# %%
import statsmodels.api as sm

# %%
x0 = bike_weather.temp
x1 = sm.add_constant(x0)
y = bike_weather.Count
model = sm.OLS(y, x1)
result = model.fit()
print(result.summary())

# %%
from sklearn.model_selection import train_test_split

x = bike_weather[['cum_precipitation', 'humidity', 'temp', 'wind']]
y = bike_weather.Count
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 123)

# %%
import statsmodels.api as sm

x1 = sm.add_constant(x_train)
model = sm. OLS(y_train, x1)
result = model.fit()
print(result.summary())

# %%
x1 = sm.add_constant(x_test)
pred = result.predict(x1)
pred

# %%
from sklearn import metrics

print('MAE :', metrics.mean_absolute_error(y_test, pred))
print('MSE :', metrics.mean_squared_error(y_test, pred))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('MAPE :', np.mean(np.abs((y_test-pred) / y_test)) *100)

# %%
bike_weather

# %%
bike_weather['Rain_YN'] = 'N'
bike_weather.loc[bike_weather.cum_precipitation > 0, 'Rain_YN'] = 'Y'
bike_weather
# Out:
#       Date_out  Time_out  Count        date  time  cum_precipitation  \
# 0   2019-10-03         1     22  2019-10-03     1           2.361667
# 1   2019-10-03         2     34  2019-10-03     2           3.353333
# 2   2019-10-03         3     32  2019-10-03     3           3.930000
# 3   2019-10-03         4     24  2019-10-03     4           4.423333
# 4   2019-10-03         5     24  2019-10-03     5           4.500000
# ..         ...       ...    ...         ...   ...                ...
# 64  2019-10-05        19    341  2019-10-05    19           0.600000
# 65  2019-10-05        20    311  2019-10-05    20           0.600000
# 66  2019-10-05        21    356  2019-10-05    21           0.600000
# 67  2019-10-05        22    318  2019-10-05    22           0.600000
# 68  2019-10-05        23    211  2019-10-05    23           0.600000
#
#      humidity  insolation     pressure  sea_lvl_pressure  sunshine       temp  \
# 0   93.846667        0.00   993.010000       1002.910000         0  20.016667
# 1   93.453333        0.00   992.668333       1002.568333         0  19.908333
# 2   91.686667        0.00   992.253333       1002.153333         0  19.923333
# 3   93.061667        0.00   992.316667       1002.216667         0  19.928333
# 4   95.028333        0.00   992.835000       1002.735000         0  19.871667
# ..        ...         ...          ...               ...       ...        ...
# 64  60.570000        8.24  1008.340000       1018.440000      8400  17.171667
# 65  61.381667        8.24  1009.146667       1019.273333      8400  16.610000
# 66  62.598333        8.24  1009.773333       1019.973333      8400  15.988333
# 67  63.560000        8.24  1010.376667       1020.576667      8400  15.436667
# 68  63.426667        8.24  1010.846667       1021.085000      8400  14.986667
#
#         wind  wind_direction Rain_YN
# 0   3.290000      178.788333       Y
# 1   3.056667      333.400000       Y
# 2   2.125000      330.110000       Y
# 3   1.931667      251.535000       Y
# 4   2.886667      236.116667       Y
# ..       ...             ...     ...
# 64  4.085000      146.493333       Y
# 65  3.631667      125.785000       Y
# 66  3.686667      225.700000       Y
# 67  3.680000      225.253333       Y
# 68  3.401667      179.688333       Y
#
# [69 rows x 15 columns]

# %%
ohe = pd.get_dummies(bike_weather['Rain_YN'])
ohe
# Out:
#     N  Y
# 0   0  1
# 1   0  1
# 2   0  1
# 3   0  1
# 4   0  1
# .. .. ..
# 64  0  1
# 65  0  1
# 66  0  1
# 67  0  1
# 68  0  1
#
# [69 rows x 2 columns]

# %%
bike_weather = pd.concat([bike_weather, ohe], axis = 1, sort = False)
bike_weather
# Out:
#       Date_out  Time_out  Count        date  time  cum_precipitation  \
# 0   2019-10-03         1     22  2019-10-03     1           2.361667
# 1   2019-10-03         2     34  2019-10-03     2           3.353333
# 2   2019-10-03         3     32  2019-10-03     3           3.930000
# 3   2019-10-03         4     24  2019-10-03     4           4.423333
# 4   2019-10-03         5     24  2019-10-03     5           4.500000
# ..         ...       ...    ...         ...   ...                ...
# 64  2019-10-05        19    341  2019-10-05    19           0.600000
# 65  2019-10-05        20    311  2019-10-05    20           0.600000
# 66  2019-10-05        21    356  2019-10-05    21           0.600000
# 67  2019-10-05        22    318  2019-10-05    22           0.600000
# 68  2019-10-05        23    211  2019-10-05    23           0.600000
#
#      humidity  insolation     pressure  sea_lvl_pressure  sunshine       temp  \
# 0   93.846667        0.00   993.010000       1002.910000         0  20.016667
# 1   93.453333        0.00   992.668333       1002.568333         0  19.908333
# 2   91.686667        0.00   992.253333       1002.153333         0  19.923333
# 3   93.061667        0.00   992.316667       1002.216667         0  19.928333
# 4   95.028333        0.00   992.835000       1002.735000         0  19.871667
# ..        ...         ...          ...               ...       ...        ...
# 64  60.570000        8.24  1008.340000       1018.440000      8400  17.171667
# 65  61.381667        8.24  1009.146667       1019.273333      8400  16.610000
# 66  62.598333        8.24  1009.773333       1019.973333      8400  15.988333
# 67  63.560000        8.24  1010.376667       1020.576667      8400  15.436667
# 68  63.426667        8.24  1010.846667       1021.085000      8400  14.986667
#
#         wind  wind_direction Rain_YN  N  Y
# 0   3.290000      178.788333       Y  0  1
# 1   3.056667      333.400000       Y  0  1
# 2   2.125000      330.110000       Y  0  1
# 3   1.931667      251.535000       Y  0  1
# 4   2.886667      236.116667       Y  0  1
# ..       ...             ...     ... .. ..
# 64  4.085000      146.493333       Y  0  1
# 65  3.631667      125.785000       Y  0  1
# 66  3.686667      225.700000       Y  0  1
# 67  3.680000      225.253333       Y  0  1
# 68  3.401667      179.688333       Y  0  1
#
# [69 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

x = bike_weather[['humidity', 'temp', 'wind','N', 'Y']]
y = bike_weather.Count
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 123)

import statsmodels.api as sm

x1 = sm.add_constant(x_train)
model = sm.OLS(y_train, x1)
result = model.fit()
print(result.summary())

x1 = sm.add_constant(x_test)
pred = result.predict(x1)

from sklearn import metrics

print('MAE :', metrics.mean_absolute_error(y_test, pred))
print('MSE :', metrics.mean_squared_error(y_test, pred))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('MAPE :', np.mean(np.abs((y_test-pred) / y_test)) *100)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Count   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     18.30
# Date:                Fri, 24 Jun 2022   Prob (F-statistic):           7.59e-09
# Time:                        10:58:54   Log-Likelihood:                -282.92
# No. Observations:                  48   AIC:                             575.8
# Df Residuals:                      43   BIC:                             585.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        608.6693    143.403      4.244      0.000     319.469     897.870
# humidity      -8.7307      1.380     -6.328      0.000     -11.513      -5.948
# temp          -0.7962      6.018     -0.132      0.895     -12.932      11.340
# wind          -7.5038     17.581     -0.427      0.672     -42.959      27.951
# N            282.8090     73.532      3.846      0.000     134.518     431.099
# Y            325.8603     72.764      4.478      0.000     179.117     472.603
# ==============================================================================
# Omnibus:                        5.480   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                5.404
# Skew:                           0.789   Prob(JB):                       0.0671
# Kurtosis:                       2.539   Cond. No.                     2.90e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.35e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# MAE : 81.1511096363972
# MSE : 12845.42402156445
# RMSE : 113.33765491470365
# MAPE : 43.07680788111809

# %%
bike_weather['over_500'] = 1
bike_weather.loc[bike_weather.Count<500, 'over_500']=0

# %%
bike_weather[bike_weather.Count == 1]
# Out:
# Empty DataFrame
# Columns: [Date_out, Time_out, Count, date, time, cum_precipitation, humidity, insolation, pressure, sea_lvl_pressure, sunshine, temp, wind, wind_direction, Rain_YN, N, Y, over_500]
# Index: []

# %%
from sklearn.model_selection import train_test_split

x = bike_weather[['cum_precipitation', 'humidity', 'temp', 'wind']]
y = bike_weather.over_500
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 123)

# %%
import statsmodels.api as sm

x1 = sm.add_constant(x_train)
logit_model = sm.Logit(y_train, x1)
result = logit_model.fit()
print(result.summary())

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
print('Train set 정확도 : %.2f' %log_reg.score(x_train, y_train))
print('Test set 정확도 : %.2f' %log_reg.score(x_test, y_test))

# %%
from sklearn.metrics import classification_report

y_pred = log_reg.predict(x_test)
print(classification_report(y_test, y_pred))

# %%
import pandas as pd
weather = pd.read_csv('data\weather.csv')
weather
# Out:
#                     date_old        date  time  temp  cum_precipitation  \
# 0     2019-10-03 오전 12:00:00  2019-10-03    12  20.0               23.2
# 1     2019-10-03 오전 12:01:00  2019-10-03    12  20.1                0.0
# 2     2019-10-03 오전 12:02:00  2019-10-03    12  20.0                0.0
# 3     2019-10-03 오전 12:03:00  2019-10-03    12  20.0                0.0
# 4     2019-10-03 오전 12:04:00  2019-10-03    12  20.0                0.0
# ...                      ...         ...   ...   ...                ...
# 4315  2019-10-05 오후 11:55:00  2019-10-05    23  14.8                0.6
# 4316  2019-10-05 오후 11:56:00  2019-10-05    23  14.8                0.6
# 4317  2019-10-05 오후 11:57:00  2019-10-05    23  14.8                0.6
# 4318  2019-10-05 오후 11:58:00  2019-10-05    23  14.7                0.6
# 4319  2019-10-05 오후 11:59:00  2019-10-05    23  14.8                0.6
#
#       humidity  insolation  sunshine  wind  wind_direction  sea_lvl_pressure  \
# 0         94.1        3.40         0   5.5           351.7            1004.1
# 1         94.1        0.00         0   3.7           348.6            1004.1
# 2         94.1        0.00         0   3.6           346.4            1004.1
# 3         94.1        0.00         0   3.1           349.1            1004.1
# 4         94.0        0.00         0   3.4           335.9            1004.1
# ...        ...         ...       ...   ...             ...               ...
# 4315      63.6        8.24      8400   3.2           350.9            1021.3
# 4316      63.5        8.24      8400   2.9           354.3            1021.3
# 4317      63.7        8.24      8400   3.1             3.9            1021.3
# 4318      63.9        8.24      8400   2.3            10.0            1021.2
# 4319      64.0        8.24      8400   2.6           351.7            1021.3
#
#       pressure
# 0        994.2
# 1        994.2
# 2        994.2
# 3        994.2
# 4        994.2
# ...        ...
# 4315    1011.0
# 4316    1011.0
# 4317    1011.0
# 4318    1011.0
# 4319    1011.0
#
# [4320 rows x 12 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np

x = np.array(weather.humidity).reshape(-1,1)
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.97205589],
#        [0.97205589],
#        [0.97205589],
#        ...,
#        [0.36526946],
#        [0.36926148],
#        [0.37125749]])

# %%
n_bike = pd.pivot_table(bike_data2, index = ['Gu', 'Date_out', 'Time_out'], values = 'Distance', aggfunc = len)
n_bike = n_bike.reset_index()
n_bike.rename(columns = {'Distance':'Count'}, inplace=True)

# %%
n_bike
# Out:
#        Gu    Date_out  Time_out  Count
# 0    동대문구  2019-10-03         0      1
# 1    동대문구  2019-10-03         1      1
# 2    동대문구  2019-10-03         2      3
# 3    동대문구  2019-10-03         3      3
# 4    동대문구  2019-10-03         4      1
# ..    ...         ...       ...    ...
# 354   은평구  2019-10-05        19     31
# 355   은평구  2019-10-05        20     28
# 356   은평구  2019-10-05        21     33
# 357   은평구  2019-10-05        22     29
# 358   은평구  2019-10-05        23     34
#
# [359 rows x 4 columns]

# %%
n_bike2 = pd.pivot_table(n_bike, index = 'Gu', columns = 'Time_out', values = 'Count', aggfunc = np.mean)
n_bike2 = n_bike2.reset_index()
n_bike2
# Out:
# Time_out    Gu          0          1          2          3          4  \
# 0         동대문구  19.000000  19.666667  12.666667  11.333333   5.000000
# 1          마포구  42.000000  37.000000  18.666667  17.000000  12.000000
# 2          서초구  20.333333  17.000000  13.333333  10.000000   5.666667
# 3         영등포구  33.666667  28.000000  21.000000  13.333333  11.000000
# 4          은평구  23.000000  19.000000  14.333333   9.333333   4.333333
#
# Time_out          5          6          7          8  ...         14  \
# 0          6.000000  10.666667  18.000000  36.000000  ...  40.000000
# 1         15.000000  18.666667  38.666667  47.000000  ...  85.666667
# 2          6.000000  13.666667  23.333333  37.666667  ...  57.333333
# 3         15.333333  22.000000  47.000000  66.000000  ...  94.333333
# 4          5.666667  10.666667  19.333333  32.000000  ...  39.000000
#
# Time_out          15          16          17          18          19  \
# 0          41.333333   44.333333   50.333333   57.000000   51.000000
# 1         107.333333  108.666667  136.666667  147.333333  120.666667
# 2          65.000000   58.333333   86.333333   88.333333   75.333333
# 3         103.666667  104.333333  129.000000  152.666667  125.333333
# 4          43.666667   44.333333   52.666667   47.000000   41.666667
#
# Time_out          20          21         22         23
# 0          43.666667   55.666667  48.000000  41.000000
# 1         108.000000  110.000000  85.333333  60.666667
# 2          66.333333   59.333333  57.000000  32.000000
# 3         105.666667  114.666667  93.666667  65.666667
# 4          46.333333   34.666667  42.333333  35.333333
#
# [5 rows x 25 columns]

# %%
from sklearn import cluster

x = n_bike2.iloc[0:5, 1:25]
y = n_bike2.Gu
km2 = cluster.KMeans(n_clusters = 2).fit(x)
km3 = cluster.KMeans(n_clusters = 3).fit(x)
km4 = cluster.KMeans(n_clusters = 4).fit(x)

# %%
n_bike2['2_Cluster'] = km2.labels_
n_bike2['3_Cluster'] = km3.labels_
n_bike2['4_Cluster'] = km4.labels_
n_bike2[['Gu', '2_Cluster', '3_Cluster', '4_Cluster']]
# Out:
# Time_out    Gu  2_Cluster  3_Cluster  4_Cluster
# 0         동대문구          1          0          0
# 1          마포구          0          1          1
# 2          서초구          1          2          2
# 3         영등포구          0          1          3
# 4          은평구          1          0          0
