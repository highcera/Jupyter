# %%
import pandas as pd
import xlwings as xw
import os

os.chdir("P:\개인자료")
bk1 = xw.Book('파이썬 활용 데이터 분석_신뢰성-IT.xlsx')

# %%
sh1 = bk1.sheets(1)
sh1.name
# Out:
# 'IT'

# %%
df = bk1.sheets(1).used_range.options(pd.DataFrame).value

# %%
df
# Out:
#                         NaN      NaN      NaN        NaN      NaN       NaN  \
# 관리번호                     재료  파우더 사이즈      파우더         조성  Sheet T     유전체두께
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# ...                     ...      ...      ...        ...      ...       ...
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
#
# ...

# %%
df = pd.DataFrame(df.iloc[1:, :50].dropna(axis = 0, how = 'all').values, columns = df.iloc[0, :50].values)

# %%
df['파우더 사이즈']= df['파우더 사이즈'].astype(int)
df[['시험전계', '유전체두께']] = df[['시험전계', '유전체두께']].astype(float)

df.dtypes
# Out:
# 재료                      object
# 파우더 사이즈                  int32
# 파우더                     object
# 조성                      object
# Sheet T                 object
# 유전체두께                  float64
# 기종                      object
# 칩사이즈                    object
# Vr                      object
# LOT NO                  object
# 시험온도                    object
# 시험전압                    object
# 시험전계                   float64
# Vr/um                   object
# m                       object
# η                       object
# MTTF                    object
# B0.1                    object
# 변환온도                    object
# 변환전압\n(10V/um)          object
# 온도가속\n(10V/um)          object
# 전압가속\n(10V/um)          object
# η\n(10V/um)             object
# MTTF\n(10V/um)          object
# B0.1\n(10V/um)          object
# B0.001\n(10V/um)        object
# 보증온도\n(85℃ 6.3V)        object
# 보증전압\n(85℃ 6.3V)        object
# 온도가속\n(85℃ 6.3V)        object
# 전압가속\n(85℃ 6.3V)        object
# ...

# %%
df[['시험전계', '유전체두께']] = df[['시험전계', '유전체두께']].round(1)

df
# Out:
#                        재료  파우더 사이즈      파우더         조성 Sheet T  유전체두께  \
# 0      SHBT100(NA372PA01)      100  SHBT100  NA372PA01     1.4    0.9
# 1      SHBT100(NA372PA01)      100  SHBT100  NA372PA01     1.4    0.9
# 2      SHBT100(NA372PA01)      100  SHBT100  NA372PA01     1.4    0.9
# 3      SHBT100(NA372PA01)      100  SHBT100  NA372PA01     1.4    0.9
# 4      SHBT100(NA372PA01)      100  SHBT100  NA372PA01     1.4    0.9
# ...                   ...      ...      ...        ...     ...    ...
# 1175  SHBT100(NA392T010)       100  SHBT100  NA392T010     1.8    1.2
# 1176  SHBT100(NA392T010)       100  SHBT100  NA392T010     1.8    1.2
# 1177  SHBT100(NA392T010)       100  SHBT100  NA392T010     1.8    1.2
# 1178  SHBT100(NA392T010)       100  SHBT100  NA392T010     1.8    1.2
# 1179  SHBT100(NA392T010)       100  SHBT100  NA392T010     1.8    1.2
#
#                 기종 칩사이즈    Vr   LOT NO  ... MTTF\n(105℃ 1.8V)  \
# 0      10A226MO7JZ   10  16.0  AD3VP4N  ...     201789.566658
# ...

# %%
df.shape
# Out:
# (1180, 50)

# %%
mat = list(set(df['파우더 사이즈']))
mat = [float(x) for x in mat if pd.isnull(x) == False]
mat
# Out:
# [160.0, 100.0, 70.0, 200.0, 300.0, 50.0, 180.0, 120.0]

# %%
mat.sort()
mat = [str(x) for x in mat if pd.isnull(x) == False]
mat
# Out:
# ['50.0', '70.0', '100.0', '120.0', '160.0', '180.0', '200.0', '300.0']

# %%
lib = pd.DataFrame(df, columns = ['재료', '파우더 사이즈', '파우더', '조성', 'Sheet T', '기종', 'LOT NO', '시험온도', '시험전압', '시험전계', 'm', 'η', 'MTTF', 'B0.1', '변환온도', '변환전압\n(10V/um)', '온도가속\n(10V/um)', '전압가속\n(10V/um)', 'η\n(10V/um)', 'MTTF\n(10V/um)', 'B0.1\n(10V/um)'])

# %%
#df['파우더 사이즈']= [int(x) for x in df['파우더 사이즈'] if pd.isnull(x) == False]
#df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-87eab48a30db> in <module>
# ----> 1 df['파우더 사이즈']= [int(x) for x in df['파우더 사이즈'] if pd.isnull(x) == False]
#       2 df
#
# <ipython-input-60-87eab48a30db> in <listcomp>(.0)
# ----> 1 df['파우더 사이즈']= [int(x) for x in df['파우더 사이즈'] if pd.isnull(x) == False]
#       2 df
#
# ValueError: invalid literal for int() with base 10: '100.0'

# %%
lib
# Out:
#                        재료 파우더 사이즈      파우더         조성 Sheet T            기종  \
# 0      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 1      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 2      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 3      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 4      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# ...                   ...     ...      ...        ...     ...           ...
# 1175  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1176  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1177  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1178  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1179  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
#
# ...

# %%
lib.dtypes
# Out:
# 재료                object
# 파우더 사이즈           object
# 파우더               object
# 조성                object
# Sheet T           object
# 기종                object
# LOT NO            object
# 시험온도              object
# 시험전압              object
# 시험전계              object
# m                 object
# η                 object
# MTTF              object
# B0.1              object
# 변환온도              object
# 변환전압\n(10V/um)    object
# 온도가속\n(10V/um)    object
# 전압가속\n(10V/um)    object
# η\n(10V/um)       object
# MTTF\n(10V/um)    object
# B0.1\n(10V/um)    object
# dtype: object

# %%
lib.isnull().sum()
# Out:
# 재료                0
# 파우더 사이즈           0
# 파우더               0
# 조성                0
# Sheet T           0
# 기종                0
# LOT NO            0
# 시험온도              0
# 시험전압              0
# 시험전계              0
# m                 0
# η                 0
# MTTF              0
# B0.1              0
# 변환온도              0
# 변환전압\n(10V/um)    0
# 온도가속\n(10V/um)    0
# 전압가속\n(10V/um)    0
# η\n(10V/um)       0
# MTTF\n(10V/um)    0
# B0.1\n(10V/um)    0
# dtype: int64

# %%
lib
# Out:
#                        재료 파우더 사이즈      파우더         조성 Sheet T            기종  \
# 0      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 1      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 2      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 3      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 4      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# ...                   ...     ...      ...        ...     ...           ...
# 1175  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1176  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1177  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1178  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1179  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
#
# ...

# %%
show = lib.drop(['변환온도', '변환전압\n(10V/um)', '온도가속\n(10V/um)', '전압가속\n(10V/um)', 'η\n(10V/um)', 'MTTF\n(10V/um)', 'B0.1\n(10V/um)'], axis=1)

# %%
show
# Out:
#                        재료 파우더 사이즈      파우더         조성 Sheet T            기종  \
# 0      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 1      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 2      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 3      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 4      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# ...                   ...     ...      ...        ...     ...           ...
# 1175  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1176  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1177  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1178  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1179  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
#
# ...

# %%
filtered = lib[lib["파우더 사이즈"] == 100.0]
filtered
# Out:
#                        재료 파우더 사이즈      파우더         조성 Sheet T            기종  \
# 0      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 1      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 2      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 3      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# 4      SHBT100(NA372PA01)   100.0  SHBT100  NA372PA01     1.4   10A226MO7JZ
# ...                   ...     ...      ...        ...     ...           ...
# 1175  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1176  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1177  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1178  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
# 1179  SHBT100(NA392T010)    100.0  SHBT100  NA392T010     1.8  10A106MAAFZ2
#
# ...

# %%
# mat 중 한가지 모재 사이즈 선택 → 파우더 선택창

diel = list(set(filtered["조성"]))
diel = [x for x in diel if pd.isnull(x) == False]

#         diel = [ str(x) for x in diel ]
diel.sort()
diel

self.cboFreq.addItems(sheetT)
    filtered_show = self.filtered_sec.drop(['변환온도', '변환전압\n(10V/um)', '온도가속\n(10V/um)', '전압가속\n(10V/um)', 'η\n(10V/um)', 'MTTF\n(10V/um)', 'B0.1\n(10V/um)'], axis = 1)
         self.make_tableLib(filtered_show)
#         self.cboDiel.addItems(diel)
show = lib.drop(['변환온도', '변환전압\n(10V/um)', '온도가속\n(10V/um)', '전압가속\n(10V/um)', 'η\n(10V/um)', 'MTTF\n(10V/um)', 'B0.1\n(10V/um)'], axis=1)
#         filtered_show = self.filtered.drop(['vol_lev', '전압 (Vdc)', 'DF','주파수(kHz)', 'AC(V)', '전압유지시간', 'Aging 시간'], axis = 1)
#         self.make_tableLib(filtered_show)
# Out:
# ['NA272P012', 'NA272PT112', 'NA372PA01', 'NA382P010', 'NA392T010']

# %%
import sys
import pandas as pd
from PyQt5.QtWidgets import QApplication, QTableView
from PyQt5.QtCore import QAbstractTableModel, Qt

class pandasModel(QAbstractTableModel):

    def __init__(self, data):
        QAbstractTableModel.__init__(self)
        self._data = data

    def rowCount(self, parent=None):
        return self._data.shape[0]

    def columnCount(self, parnet=None):
        return self._data.shape[1]

    def data(self, index, role=Qt.DisplayRole):
        if index.isValid():
            if role == Qt.DisplayRole:
                return str(self._data.iloc[index.row(), index.column()])
        return None

    def headerData(self, col, orientation, role):
        if orientation == Qt.Horizontal and role == Qt.DisplayRole:
            return self._data.columns[col]
        return None

if __name__ == '__main__':
    app = QApplication(sys.argv)
    model = pandasModel(show)
    view = QTableView()
    view.setModel(model)
    view.resize(800, 600)
    view.show()
    mainloop()
    sys.exit(app.exec_())

# %%
model

# %%
txt = "SHBT70(NA272PUG1)"
filtered = lib[lib["조성"] == txt]

# %%
filtered
# Out:
#                     조성   유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께        DF  \
# 34   SHBT70(NA272PUG1)  3322       P        저주파         0     0.75     0.057
# 35   SHBT70(NA272PUG1)  3322       P        고주파         0     0.75     0.057
# 36   SHBT70(NA272PUG1)  3334       P        저주파         0     0.75     0.062
# 37   SHBT70(NA272PUG1)  3334       P        고주파         0     0.75     0.062
# 64   SHBT70(NA272PUG1)     0       Q        저주파         0     0.86     0.083
# 65   SHBT70(NA272PUG1)     0       Q        고주파         0     0.86     0.083
# 219  SHBT70(NA272PUG1)  3079       Q        저주파         0      0.7  0.056659
# 220  SHBT70(NA272PUG1)  3079       Q        고주파         0      0.7  0.056659
# 225  SHBT70(NA272PUG1)  2968       P        저주파         0     1.05  0.054322
# 226  SHBT70(NA272PUG1)  2968       P        고주파         0     1.05  0.054322
# 227  SHBT70(NA272PUG1)  3602       P        저주파         0      1.1   0.08258
# ...

# %%
diel = list(set(filtered["유전율"]))

# %%
diel
# Out:
# [0,
#  4193,
#  2725,
#  3334,
#  3079,
#  4250,
#  3662,
#  3450,
#  3602,
#  3027,
#  3871,
#  2968,
#  3322,
#  3451,
#  4031]

# %%
diel = [x for x in diel if pd.isnull(x) == False]

# %%
diel
# Out:
# [0,
#  4193,
#  2725,
#  3334,
#  3079,
#  4250,
#  3662,
#  3450,
#  3602,
#  3027,
#  3871,
#  2968,
#  3322,
#  3451,
#  4031]

# %%
diel = [ str(x) for x in diel ]

# %%
diel
# Out:
# ['0',
#  '4193',
#  '2725',
#  '3334',
#  '3079',
#  '4250',
#  '3662',
#  '3450',
#  '3602',
#  '3027',
#  '3871',
#  '2968',
#  '3322',
#  '3451',
#  '4031']

# %%
 diel.sort()

# %%
diel
# Out:
# ['0',
#  '2725',
#  '2968',
#  '3027',
#  '3079',
#  '3322',
#  '3334',
#  '3450',
#  '3451',
#  '3602',
#  '3662',
#  '3871',
#  '4031',
#  '4193',
#  '4250']

# %%
txt = "4031"
filtered_sec = filtered[filtered["유전율"] == int(txt) ]

# %%
filtered_sec
# Out:
#                     조성   유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께        DF  \
# 235  SHBT70(NA272PUG1)  4031       Q        저주파         0     0.88  0.079575
# 236  SHBT70(NA272PUG1)  4031       Q        고주파         0     0.88  0.079575
#
#     주파수(kHz) AC(V) 전압유지시간 Aging 시간
# 235     0.12   0.5    60s     24hr
# 236    100.0  0.01    60s     24hr

# %%
txt = "저주파"
filtered_thr = filtered_sec[ filtered_sec["DC-Bias 측정"] == txt ]

# %%
filtered_thr
# Out:
#                     조성   유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께        DF  \
# 235  SHBT70(NA272PUG1)  4031       Q        저주파         0     0.88  0.079575
#
#     주파수(kHz) AC(V) 전압유지시간 Aging 시간
# 235     0.12   0.5    60s     24hr

# %%
filtered_thr['주파수(kHz)'].iloc[0]
# Out:
# 0.12

# %%
filtered_thr['AC(V)'].iloc[0]
# Out:
# 0.5

# %%
filtered_thr['전압유지시간'].iloc[0]
# Out:
# '60s'

# %%
filtered_thr['Aging 시간'].iloc[0]
# Out:
# '24hr'

# %%
filtered_sec['DF'].iloc[0]
# Out:
# 0.079575

# %%
filtered_sec["DC-Bias 측정"]
# Out:
# 235    저주파
# 236    고주파
# Name: DC-Bias 측정, dtype: object

# %%
filtered_thr.reset_index(drop = True, inplace =True)

# %%
filtered_thr
# Out:
#                   조성   유전율 vol_lev DC-Bias 측정  전압 (Vdc) sheet 두께        DF  \
# 0  SHBT70(NA272PUG1)  4031       Q        저주파         0     0.88  0.079575
#
#   주파수(kHz) AC(V) 전압유지시간 Aging 시간
# 0     0.12   0.5    60s     24hr

# %%
import pandas as pd
import xlwings as xw
import os

os.chdir("P:\개인자료")
bk1 = xw.Book('파이썬 활용 데이터 분석_신뢰성-IT.xlsx')

# %%
df = bk1.sheets(1).used_range.options(pd.DataFrame).value
df
# Out:
#                         NaN      NaN      NaN        NaN      NaN       NaN  \
# 관리번호                     재료  파우더 사이즈      파우더         조성  Sheet T     유전체두께
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1705-17  SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# ...                     ...      ...      ...        ...      ...       ...
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
# NaN                    None     None     None       None     None      None
#
# ...

# %%
df = pd.DataFrame(df.iloc[1:, :50].dropna(axis = 0, how = 'all').values, columns = df.iloc[0, :50].values)

# %%
df2 = df.apply(pd.to_numeric, errors='ignore')
df2
# Out:
#                        재료  파우더 사이즈      파우더         조성  Sheet T     유전체두께  \
# 0      SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 1      SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 2      SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 3      SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# 4      SHBT100(NA372PA01)    100.0  SHBT100  NA372PA01      1.4  0.933333
# ...                   ...      ...      ...        ...      ...       ...
# 1175  SHBT100(NA392T010)     100.0  SHBT100  NA392T010      1.8  1.200000
# 1176  SHBT100(NA392T010)     100.0  SHBT100  NA392T010      1.8  1.200000
# 1177  SHBT100(NA392T010)     100.0  SHBT100  NA392T010      1.8  1.200000
# 1178  SHBT100(NA392T010)     100.0  SHBT100  NA392T010      1.8  1.200000
# 1179  SHBT100(NA392T010)     100.0  SHBT100  NA392T010      1.8  1.200000
#
#                 기종  칩사이즈    Vr   LOT NO  ...  MTTF\n(105℃ 1.8V)  \
# ...

# %%
df2.dtypes
# Out:
# 재료                      object
# 파우더 사이즈                float64
# 파우더                     object
# 조성                      object
# Sheet T                float64
# 유전체두께                  float64
# 기종                      object
# 칩사이즈                     int64
# Vr                     float64
# LOT NO                  object
# 시험온도                   float64
# 시험전압                   float64
# 시험전계                   float64
# Vr/um                  float64
# m                      float64
# η                      float64
# MTTF                   float64
# B0.1                   float64
# 변환온도                   float64
# 변환전압\n(10V/um)         float64
# 온도가속\n(10V/um)         float64
# 전압가속\n(10V/um)         float64
# η\n(10V/um)            float64
# MTTF\n(10V/um)         float64
# B0.1\n(10V/um)         float64
# B0.001\n(10V/um)       float64
# 보증온도\n(85℃ 6.3V)       float64
# 보증전압\n(85℃ 6.3V)       float64
# 온도가속\n(85℃ 6.3V)       float64
# 전압가속\n(85℃ 6.3V)       float64
# ...

# %%
import numpy as np

# %%
p = list(np.arange(0, 10.1, 0.1))

# %%
o = list(np.arange(0, 16.1, 0.1))
a = list(np.arange(0, 25.1, 0.1))
l = list(np.arange(0, 35.1, 0.1))
bce = list(np.arange(0, 40.1, 0.1))

# %%
p
# Out:
# [0.0,
#  0.1,
#  0.2,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.6000000000000001,
#  0.7000000000000001,
#  0.8,
#  0.9,
#  1.0,
#  1.1,
#  1.2000000000000002,
#  1.3,
#  1.4000000000000001,
#  1.5,
#  1.6,
#  1.7000000000000002,
#  1.8,
#  1.9000000000000001,
#  2.0,
#  2.1,
#  2.2,
#  2.3000000000000003,
#  2.4000000000000004,
#  2.5,
#  2.6,
#  2.7,
#  2.8000000000000003,
#  2.9000000000000004,
#  3.0,
#  3.1,
#  3.2,
#  3.3000000000000003,
#  3.4000000000000004,
#  3.5,
#  3.6,
#  3.7,
#  3.8000000000000003,
#  3.9000000000000004,
#  4.0,
#  4.1000000000000005,
#  4.2,
#  4.3,
#  4.4,
#  4.5,
#  4.6000000000000005,
#  4.7,
#  4.800000000000001,
#  4.9,
#  5.0,
#  5.1000000000000005,
#  5.2,
#  5.300000000000001,
#  5.4,
#  5.5,
#  5.6000000000000005,
#  5.7,
#  5.800000000000001,
#  5.9,
#  6.0,
#  6.1000000000000005,
#  6.2,
#  6.300000000000001,
#  6.4,
#  6.5,
#  6.6000000000000005,
#  6.7,
#  6.800000000000001,
#  6.9,
#  7.0,
#  7.1000000000000005,
#  7.2,
# ...

# %%
test = pd.DataFrame()

# %%
vol_lev = 'Q'
df3 = pd.concat([filtered_thr.iloc[0]]*len(p), axis = 1)

# %%
len(p)
# Out:
# 101

# %%
df3
# Out:
#                             0                  0                  0  \
# 조성          SHBT70(NA272PUG1)  SHBT70(NA272PUG1)  SHBT70(NA272PUG1)
# 유전율                      4031               4031               4031
# vol_lev                     Q                  Q                  Q
# DC-Bias 측정                저주파                저주파                저주파
# 전압 (Vdc)                    0                  0                  0
# sheet 두께                 0.88               0.88               0.88
# DF                   0.079575           0.079575           0.079575
# 주파수(kHz)                 0.12               0.12               0.12
# AC(V)                     0.5                0.5                0.5
# 전압유지시간                    60s                60s                60s
# Aging 시간                 24hr               24hr               24hr
#
#                             0                  0                  0  \
# 조성          SHBT70(NA272PUG1)  SHBT70(NA272PUG1)  SHBT70(NA272PUG1)
# ...

# %%
fin = test.T.reset_index(drop = True)

# %%
fin
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(len(fin[vol_lev])):
    if fin['전압 (Vdc)'][i] == 0:
        for j in range(len(p)):
           fin['전압 (Vdc)'][i + j] = p[j]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-f486c77ade7b> in <module>
# ----> 1 for i in range(len(fin[vol_lev])):
# ...
